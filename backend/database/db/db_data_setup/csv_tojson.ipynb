# %%
import pandas as pd
import sys
import random
import os
import re
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import nltk
import random

# %%
#nltk.download()

# %%
data = pd.read_csv('csv_data/dataset.csv')

# %% [markdown]
# Get some example sentences from the data

# %%
data.head()

# %%
diseases = []
for i in range(len(data['Disease'])):
    diseases.append(data['Disease'][i])

disease = set(diseases)

# %%
def get_symptoms_for1(symptom_num,disease):
    symptoms = []
    strval = "Symptom_" + str(symptom_num)
    for i in range(len(data[strval])):
        if data["Disease"][i] == disease:

            if str(data[strval][i]) != "nan":
                symptoms.append((str(data[strval][i])).replace("_"," "))

    return symptoms


def get_symptoms_per_disease(diseaseSet=disease):
    symptomDisease = {}

    out = []
    for h in diseaseSet:
        for k in range(1,18):
            out.extend(get_symptoms_for1(k,h))

        symptomDisease[h] = list(set(out))
        out=[] 

    return symptomDisease

# %%
values = get_symptoms_per_disease()

# %%
len(list(values.keys()))
# Out:
# 41

# %%
values2 = {}
for condition in list(values.keys()):
    words = values.get(condition)
    newarr = []
    for word in words:
        #print(word)
        word2 = word[1:]
        newarr.append(word2)
    values2[condition] = newarr

# %% [markdown]
# Now that we have all the symptom words per disease, we can hard code a couple hundred example sentences with symptom words to train the Markov Chain Model

# %%
def randWords(inpList):
    randomWords = []

    randomVals = random.sample(range(0,len(inpList)-1), 3)
    for randomIdx in randomVals:
        randomWords.append(inpList[randomIdx])

    return randomWords

def makeSentence(randomWords):
    #list description
    listDesc = (randomWords[0] + ", " + 
    randomWords[1] + ", " + 
    randomWords[2])

    #vague description
    vagueDesc = ("I feel " + randomWords[0] + 
    " and I also feel like " + 
    randomWords[1] + " but I also feel like " + 
    randomWords[2] + ".")

    return listDesc, vagueDesc

def makeSentences(inpList):
    generated_sents = []

    for i in range(41):
        listDesc, vagueDesc = makeSentence(randWords(inpList))
        generated_sents.append(listDesc)
        generated_sents.append(vagueDesc)
    
    return generated_sents

# %%
diseaseSents = {}

valueKeys = list(values2.keys())
for disease in valueKeys:
    conditions = values2.get(disease)
    diseaseSents[disease] = makeSentences(conditions)

# %%
allSymptoms = []
for setsymps in list(values2.values()):
    for symptom in setsymps:
        allSymptoms.append(symptom)
allSymptoms = set(allSymptoms)

# %% [markdown]
# Get the Markov chain set up for dataset generation

# %%
#define a few helper funcs
def clean_data(data):
    cleaned = []
 
    for line in data:
        line = line.lower() #makes it lowercase
 
        line = re.sub(r"[,.\"\'!@#$%^&*(){}?/;`~:<>+=-\\]", "", line) #takes out any symbols
 
        tokens = word_tokenize(line)
 
        words = [word for word in tokens if word.isalpha()] #check if only letters (no special chars/symbols)
 
        cleaned += words
 
    return cleaned

# %% [markdown]
# Clean the data per line and get it into a dictionary with condition: sentences

# %%
diseaseSents
# Out:
# {'Gastroenteritis': ['dehydration, diarrhoea, vomiting',
#   'I feel dehydration and I also feel like diarrhoea but I also feel like vomiting.',
#   'vomiting, diarrhoea, dehydration',
#   'I feel vomiting and I also feel like diarrhoea but I also feel like dehydration.',
#   'diarrhoea, dehydration, vomiting',
#   'I feel diarrhoea and I also feel like dehydration but I also feel like vomiting.',
#   'diarrhoea, dehydration, vomiting',
#   'I feel diarrhoea and I also feel like dehydration but I also feel like vomiting.',
#   'diarrhoea, dehydration, vomiting',
#   'I feel diarrhoea and I also feel like dehydration but I also feel like vomiting.',
#   'vomiting, diarrhoea, dehydration',
#   'I feel vomiting and I also feel like diarrhoea but I also feel like dehydration.',
#   'dehydration, vomiting, diarrhoea',
#   'I feel dehydration and I also feel like vomiting but I also feel like diarrhoea.',
#   'diarrhoea, vomiting, dehydration',
#   'I feel diarrhoea and I also feel like vomiting but I also feel like dehydration.',
#   'diarrhoea, vomiting, dehydration',
#   'I feel diarrhoea and I also feel like vomiting but I also feel like dehydration.',
#   'diarrhoea, dehydration, vomiting',
#   'I feel diarrhoea and I also feel like dehydration but I also feel like vomiting.',
#   'diarrhoea, dehydration, vomiting',
#   'I feel diarrhoea and I also feel like dehydration but I also feel like vomiting.',
#   'diarrhoea, dehydration, vomiting',
#   'I feel diarrhoea and I also feel like dehydration but I also feel like vomiting.',
#   'diarrhoea, dehydration, vomiting',
#   'I feel diarrhoea and I also feel like dehydration but I also feel like vomiting.',
#   'vomiting, dehydration, diarrhoea',
#   'I feel vomiting and I also feel like dehydration but I also feel like diarrhoea.',
#   'vomiting, diarrhoea, dehydration',
#   'I feel vomiting and I also feel like diarrhoea but I also feel like dehydration.',
#   'dehydration, diarrhoea, vomiting',
#   'I feel dehydration and I also feel like diarrhoea but I also feel like vomiting.',
#   'vomiting, diarrhoea, dehydration',
#   'I feel vomiting and I also feel like diarrhoea but I also feel like dehydration.',
#   'vomiting, dehydration, diarrhoea',
#   'I feel vomiting and I also feel like dehydration but I also feel like diarrhoea.',
#   'dehydration, diarrhoea, vomiting',
#   'I feel dehydration and I also feel like diarrhoea but I also feel like vomiting.',
#   'diarrhoea, vomiting, dehydration',
#   'I feel diarrhoea and I also feel like vomiting but I also feel like dehydration.',
#   'dehydration, vomiting, diarrhoea',
#   'I feel dehydration and I also feel like vomiting but I also feel like diarrhoea.',
#   'diarrhoea, vomiting, dehydration',
#   'I feel diarrhoea and I also feel like vomiting but I also feel like dehydration.',
#   'dehydration, diarrhoea, vomiting',
#   'I feel dehydration and I also feel like diarrhoea but I also feel like vomiting.',
#   'vomiting, diarrhoea, dehydration',
#   'I feel vomiting and I also feel like diarrhoea but I also feel like dehydration.',
#   'vomiting, dehydration, diarrhoea',
#   'I feel vomiting and I also feel like dehydration but I also feel like diarrhoea.',
#   'dehydration, vomiting, diarrhoea',
#   'I feel dehydration and I also feel like vomiting but I also feel like diarrhoea.',
#   'diarrhoea, dehydration, vomiting',
#   'I feel diarrhoea and I also feel like dehydration but I also feel like vomiting.',
#   'vomiting, diarrhoea, dehydration',
#   'I feel vomiting and I also feel like diarrhoea but I also feel like dehydration.',
#   'diarrhoea, vomiting, dehydration',
#   'I feel diarrhoea and I also feel like vomiting but I also feel like dehydration.',
#   'diarrhoea, vomiting, dehydration',
#   'I feel diarrhoea and I also feel like vomiting but I also feel like dehydration.',
#   'diarrhoea, dehydration, vomiting',
#   'I feel diarrhoea and I also feel like dehydration but I also feel like vomiting.',
#   'diarrhoea, vomiting, dehydration',
#   'I feel diarrhoea and I also feel like vomiting but I also feel like dehydration.',
#   'dehydration, vomiting, diarrhoea',
#   'I feel dehydration and I also feel like vomiting but I also feel like diarrhoea.',
#   'vomiting, dehydration, diarrhoea',
#   'I feel vomiting and I also feel like dehydration but I also feel like diarrhoea.',
#   'vomiting, diarrhoea, dehydration',
#   'I feel vomiting and I also feel like diarrhoea but I also feel like dehydration.',
#   'diarrhoea, vomiting, dehydration',
#   'I feel diarrhoea and I also feel like vomiting but I also feel like dehydration.',
#   'diarrhoea, vomiting, dehydration',
#   'I feel diarrhoea and I also feel like vomiting but I also feel like dehydration.',
#   'dehydration, vomiting, diarrhoea',
#   'I feel dehydration and I also feel like vomiting but I also feel like diarrhoea.',
#   'dehydration, vomiting, diarrhoea',
#   'I feel dehydration and I also feel like vomiting but I also feel like diarrhoea.',
#   'diarrhoea, dehydration, vomiting',
#   'I feel diarrhoea and I also feel like dehydration but I also feel like vomiting.',
#   'vomiting, dehydration, diarrhoea',
#   'I feel vomiting and I also feel like dehydration but I also feel like diarrhoea.'],
#  'GERD': ['vomiting, ulcers on tongue, chest pain',
#   'I feel vomiting and I also feel like ulcers on tongue but I also feel like chest pain.',
#   'vomiting, stomach pain, ulcers on tongue',
#   'I feel vomiting and I also feel like stomach pain but I also feel like ulcers on tongue.',
#   'ulcers on tongue, chest pain, vomiting',
#   'I feel ulcers on tongue and I also feel like chest pain but I also feel like vomiting.',
#   'chest pain, acidity, stomach pain',
#   'I feel chest pain and I also feel like acidity but I also feel like stomach pain.',
#   'stomach pain, acidity, chest pain',
#   'I feel stomach pain and I also feel like acidity but I also feel like chest pain.',
#   'vomiting, chest pain, ulcers on tongue',
#   'I feel vomiting and I also feel like chest pain but I also feel like ulcers on tongue.',
#   'vomiting, chest pain, stomach pain',
#   'I feel vomiting and I also feel like chest pain but I also feel like stomach pain.',
#   'vomiting, ulcers on tongue, chest pain',
#   'I feel vomiting and I also feel like ulcers on tongue but I also feel like chest pain.',
#   'ulcers on tongue, acidity, vomiting',
#   'I feel ulcers on tongue and I also feel like acidity but I also feel like vomiting.',
#   'chest pain, stomach pain, vomiting',
#   'I feel chest pain and I also feel like stomach pain but I also feel like vomiting.',
#   'stomach pain, acidity, ulcers on tongue',
#   'I feel stomach pain and I also feel like acidity but I also feel like ulcers on tongue.',
#   'acidity, ulcers on tongue, stomach pain',
#   'I feel acidity and I also feel like ulcers on tongue but I also feel like stomach pain.',
#   'vomiting, stomach pain, ulcers on tongue',
#   'I feel vomiting and I also feel like stomach pain but I also feel like ulcers on tongue.',
#   'acidity, stomach pain, vomiting',
#   'I feel acidity and I also feel like stomach pain but I also feel like vomiting.',
#   'vomiting, ulcers on tongue, acidity',
#   'I feel vomiting and I also feel like ulcers on tongue but I also feel like acidity.',
#   'chest pain, acidity, vomiting',
#   'I feel chest pain and I also feel like acidity but I also feel like vomiting.',
#   'ulcers on tongue, stomach pain, vomiting',
#   'I feel ulcers on tongue and I also feel like stomach pain but I also feel like vomiting.',
#   'vomiting, stomach pain, ulcers on tongue',
#   'I feel vomiting and I also feel like stomach pain but I also feel like ulcers on tongue.',
#   'ulcers on tongue, chest pain, vomiting',
#   'I feel ulcers on tongue and I also feel like chest pain but I also feel like vomiting.',
#   'stomach pain, chest pain, ulcers on tongue',
#   'I feel stomach pain and I also feel like chest pain but I also feel like ulcers on tongue.',
#   'acidity, chest pain, vomiting',
#   'I feel acidity and I also feel like chest pain but I also feel like vomiting.',
#   'ulcers on tongue, acidity, vomiting',
#   'I feel ulcers on tongue and I also feel like acidity but I also feel like vomiting.',
#   'vomiting, chest pain, stomach pain',
#   'I feel vomiting and I also feel like chest pain but I also feel like stomach pain.',
#   'stomach pain, acidity, chest pain',
#   'I feel stomach pain and I also feel like acidity but I also feel like chest pain.',
#   'acidity, chest pain, ulcers on tongue',
#   'I feel acidity and I also feel like chest pain but I also feel like ulcers on tongue.',
#   'chest pain, stomach pain, ulcers on tongue',
#   'I feel chest pain and I also feel like stomach pain but I also feel like ulcers on tongue.',
#   'chest pain, stomach pain, acidity',
#   'I feel chest pain and I also feel like stomach pain but I also feel like acidity.',
#   'chest pain, stomach pain, ulcers on tongue',
#   'I feel chest pain and I also feel like stomach pain but I also feel like ulcers on tongue.',
#   'acidity, vomiting, chest pain',
#   'I feel acidity and I also feel like vomiting but I also feel like chest pain.',
#   'chest pain, ulcers on tongue, acidity',
#   'I feel chest pain and I also feel like ulcers on tongue but I also feel like acidity.',
#   'vomiting, acidity, ulcers on tongue',
#   'I feel vomiting and I also feel like acidity but I also feel like ulcers on tongue.',
#   'ulcers on tongue, chest pain, stomach pain',
#   'I feel ulcers on tongue and I also feel like chest pain but I also feel like stomach pain.',
#   'ulcers on tongue, acidity, stomach pain',
#   'I feel ulcers on tongue and I also feel like acidity but I also feel like stomach pain.',
#   'acidity, stomach pain, vomiting',
#   'I feel acidity and I also feel like stomach pain but I also feel like vomiting.',
#   'vomiting, acidity, stomach pain',
#   'I feel vomiting and I also feel like acidity but I also feel like stomach pain.',
#   'stomach pain, chest pain, vomiting',
#   'I feel stomach pain and I also feel like chest pain but I also feel like vomiting.',
#   'vomiting, stomach pain, ulcers on tongue',
#   'I feel vomiting and I also feel like stomach pain but I also feel like ulcers on tongue.',
#   'vomiting, acidity, ulcers on tongue',
#   'I feel vomiting and I also feel like acidity but I also feel like ulcers on tongue.',
#   'vomiting, ulcers on tongue, stomach pain',
#   'I feel vomiting and I also feel like ulcers on tongue but I also feel like stomach pain.',
#   'acidity, vomiting, stomach pain',
#   'I feel acidity and I also feel like vomiting but I also feel like stomach pain.',
#   'stomach pain, acidity, chest pain',
#   'I feel stomach pain and I also feel like acidity but I also feel like chest pain.'],
#  'Bronchial Asthma': ['mucoid sputum, fatigue, cough',
#   'I feel mucoid sputum and I also feel like fatigue but I also feel like cough.',
#   'breathlessness, cough, family history',
#   'I feel breathlessness and I also feel like cough but I also feel like family history.',
#   'breathlessness, cough, mucoid sputum',
#   'I feel breathlessness and I also feel like cough but I also feel like mucoid sputum.',
#   'cough, family history, mucoid sputum',
#   'I feel cough and I also feel like family history but I also feel like mucoid sputum.',
#   'breathlessness, family history, fatigue',
#   'I feel breathlessness and I also feel like family history but I also feel like fatigue.',
#   'mucoid sputum, cough, breathlessness',
#   'I feel mucoid sputum and I also feel like cough but I also feel like breathlessness.',
#   'fatigue, mucoid sputum, family history',
#   'I feel fatigue and I also feel like mucoid sputum but I also feel like family history.',
#   'cough, family history, fatigue',
#   'I feel cough and I also feel like family history but I also feel like fatigue.',
#   'family history, cough, breathlessness',
#   'I feel family history and I also feel like cough but I also feel like breathlessness.',
#   'cough, family history, fatigue',
#   'I feel cough and I also feel like family history but I also feel like fatigue.',
#   'breathlessness, cough, family history',
#   'I feel breathlessness and I also feel like cough but I also feel like family history.',
#   'fatigue, family history, cough',
#   'I feel fatigue and I also feel like family history but I also feel like cough.',
#   'mucoid sputum, cough, fatigue',
#   'I feel mucoid sputum and I also feel like cough but I also feel like fatigue.',
#   'breathlessness, mucoid sputum, fatigue',
#   'I feel breathlessness and I also feel like mucoid sputum but I also feel like fatigue.',
#   'cough, fatigue, family history',
#   'I feel cough and I also feel like fatigue but I also feel like family history.',
#   'family history, breathlessness, cough',
#   'I feel family history and I also feel like breathlessness but I also feel like cough.',
#   'cough, fatigue, breathlessness',
#   'I feel cough and I also feel like fatigue but I also feel like breathlessness.',
#   'breathlessness, mucoid sputum, family history',
#   'I feel breathlessness and I also feel like mucoid sputum but I also feel like family history.',
#   'fatigue, breathlessness, mucoid sputum',
#   'I feel fatigue and I also feel like breathlessness but I also feel like mucoid sputum.',
#   'breathlessness, mucoid sputum, fatigue',
#   'I feel breathlessness and I also feel like mucoid sputum but I also feel like fatigue.',
#   'cough, breathlessness, family history',
#   'I feel cough and I also feel like breathlessness but I also feel like family history.',
#   'fatigue, mucoid sputum, cough',
#   'I feel fatigue and I also feel like mucoid sputum but I also feel like cough.',
#   'cough, mucoid sputum, fatigue',
#   'I feel cough and I also feel like mucoid sputum but I also feel like fatigue.',
#   'breathlessness, mucoid sputum, family history',
#   'I feel breathlessness and I also feel like mucoid sputum but I also feel like family history.',
#   'breathlessness, fatigue, family history',
#   'I feel breathlessness and I also feel like fatigue but I also feel like family history.',
#   'cough, family history, mucoid sputum',
#   'I feel cough and I also feel like family history but I also feel like mucoid sputum.',
#   'mucoid sputum, breathlessness, family history',
#   'I feel mucoid sputum and I also feel like breathlessness but I also feel like family history.',
#   'fatigue, mucoid sputum, cough',
#   'I feel fatigue and I also feel like mucoid sputum but I also feel like cough.',
#   'family history, mucoid sputum, breathlessness',
#   'I feel family history and I also feel like mucoid sputum but I also feel like breathlessness.',
#   'cough, family history, mucoid sputum',
#   'I feel cough and I also feel like family history but I also feel like mucoid sputum.',
#   'family history, cough, mucoid sputum',
#   'I feel family history and I also feel like cough but I also feel like mucoid sputum.',
#   'mucoid sputum, family history, breathlessness',
#   'I feel mucoid sputum and I also feel like family history but I also feel like breathlessness.',
#   'fatigue, family history, breathlessness',
#   'I feel fatigue and I also feel like family history but I also feel like breathlessness.',
#   'mucoid sputum, family history, cough',
#   'I feel mucoid sputum and I also feel like family history but I also feel like cough.',
#   'cough, fatigue, family history',
#   'I feel cough and I also feel like fatigue but I also feel like family history.',
#   'mucoid sputum, fatigue, cough',
#   'I feel mucoid sputum and I also feel like fatigue but I also feel like cough.',
#   'family history, breathlessness, cough',
#   'I feel family history and I also feel like breathlessness but I also feel like cough.',
#   'fatigue, mucoid sputum, cough',
#   'I feel fatigue and I also feel like mucoid sputum but I also feel like cough.',
#   'breathlessness, mucoid sputum, cough',
#   'I feel breathlessness and I also feel like mucoid sputum but I also feel like cough.',
#   'fatigue, breathlessness, family history',
#   'I feel fatigue and I also feel like breathlessness but I also feel like family history.',
#   'breathlessness, family history, mucoid sputum',
#   'I feel breathlessness and I also feel like family history but I also feel like mucoid sputum.'],
#  'Peptic ulcer diseae': ['loss of appetite, vomiting, internal itching',
#   'I feel loss of appetite and I also feel like vomiting but I also feel like internal itching.',
#   'internal itching, vomiting, passage of gases',
#   'I feel internal itching and I also feel like vomiting but I also feel like passage of gases.',
#   'vomiting, internal itching, loss of appetite',
#   'I feel vomiting and I also feel like internal itching but I also feel like loss of appetite.',
#   'internal itching, indigestion, loss of appetite',
#   'I feel internal itching and I also feel like indigestion but I also feel like loss of appetite.',
#   'vomiting, internal itching, loss of appetite',
#   'I feel vomiting and I also feel like internal itching but I also feel like loss of appetite.',
#   'indigestion, loss of appetite, vomiting',
#   'I feel indigestion and I also feel like loss of appetite but I also feel like vomiting.',
#   'internal itching, vomiting, loss of appetite',
#   'I feel internal itching and I also feel like vomiting but I also feel like loss of appetite.',
#   'vomiting, loss of appetite, internal itching',
#   'I feel vomiting and I also feel like loss of appetite but I also feel like internal itching.',
#   'passage of gases, indigestion, vomiting',
#   'I feel passage of gases and I also feel like indigestion but I also feel like vomiting.',
#   'passage of gases, indigestion, loss of appetite',
#   'I feel passage of gases and I also feel like indigestion but I also feel like loss of appetite.',
#   'loss of appetite, vomiting, passage of gases',
#   'I feel loss of appetite and I also feel like vomiting but I also feel like passage of gases.',
#   'indigestion, passage of gases, internal itching',
#   'I feel indigestion and I also feel like passage of gases but I also feel like internal itching.',
#   'vomiting, internal itching, indigestion',
#   'I feel vomiting and I also feel like internal itching but I also feel like indigestion.',
#   'loss of appetite, internal itching, vomiting',
#   'I feel loss of appetite and I also feel like internal itching but I also feel like vomiting.',
#   'loss of appetite, internal itching, passage of gases',
#   'I feel loss of appetite and I also feel like internal itching but I also feel like passage of gases.',
#   'vomiting, loss of appetite, internal itching',
#   'I feel vomiting and I also feel like loss of appetite but I also feel like internal itching.',
#   'loss of appetite, internal itching, indigestion',
#   'I feel loss of appetite and I also feel like internal itching but I also feel like indigestion.',
#   'indigestion, vomiting, passage of gases',
#   'I feel indigestion and I also feel like vomiting but I also feel like passage of gases.',
#   'vomiting, passage of gases, loss of appetite',
#   'I feel vomiting and I also feel like passage of gases but I also feel like loss of appetite.',
#   'internal itching, loss of appetite, indigestion',
#   'I feel internal itching and I also feel like loss of appetite but I also feel like indigestion.',
#   'indigestion, loss of appetite, passage of gases',
#   'I feel indigestion and I also feel like loss of appetite but I also feel like passage of gases.',
#   'passage of gases, vomiting, indigestion',
#   'I feel passage of gases and I also feel like vomiting but I also feel like indigestion.',
#   'indigestion, internal itching, vomiting',
#   'I feel indigestion and I also feel like internal itching but I also feel like vomiting.',
#   'internal itching, passage of gases, indigestion',
#   'I feel internal itching and I also feel like passage of gases but I also feel like indigestion.',
#   'passage of gases, indigestion, internal itching',
#   'I feel passage of gases and I also feel like indigestion but I also feel like internal itching.',
#   'loss of appetite, passage of gases, internal itching',
#   'I feel loss of appetite and I also feel like passage of gases but I also feel like internal itching.',
#   'vomiting, indigestion, passage of gases',
#   'I feel vomiting and I also feel like indigestion but I also feel like passage of gases.',
#   'passage of gases, indigestion, loss of appetite',
#   'I feel passage of gases and I also feel like indigestion but I also feel like loss of appetite.',
#   'loss of appetite, indigestion, internal itching',
#   'I feel loss of appetite and I also feel like indigestion but I also feel like internal itching.',
#   'indigestion, passage of gases, vomiting',
#   'I feel indigestion and I also feel like passage of gases but I also feel like vomiting.',
#   'loss of appetite, indigestion, internal itching',
#   'I feel loss of appetite and I also feel like indigestion but I also feel like internal itching.',
#   'loss of appetite, vomiting, internal itching',
#   'I feel loss of appetite and I also feel like vomiting but I also feel like internal itching.',
#   'indigestion, loss of appetite, internal itching',
#   'I feel indigestion and I also feel like loss of appetite but I also feel like internal itching.',
#   'indigestion, internal itching, vomiting',
#   'I feel indigestion and I also feel like internal itching but I also feel like vomiting.',
#   'indigestion, loss of appetite, internal itching',
#   'I feel indigestion and I also feel like loss of appetite but I also feel like internal itching.',
#   'loss of appetite, vomiting, passage of gases',
#   'I feel loss of appetite and I also feel like vomiting but I also feel like passage of gases.',
#   'vomiting, internal itching, passage of gases',
#   'I feel vomiting and I also feel like internal itching but I also feel like passage of gases.',
#   'vomiting, internal itching, indigestion',
#   'I feel vomiting and I also feel like internal itching but I also feel like indigestion.',
#   'loss of appetite, internal itching, indigestion',
#   'I feel loss of appetite and I also feel like internal itching but I also feel like indigestion.',
#   'loss of appetite, indigestion, internal itching',
#   'I feel loss of appetite and I also feel like indigestion but I also feel like internal itching.',
#   'loss of appetite, vomiting, internal itching',
#   'I feel loss of appetite and I also feel like vomiting but I also feel like internal itching.'],
#  'hepatitis A': ['abdominal pain, vomiting, dark urine',
#   'I feel abdominal pain and I also feel like vomiting but I also feel like dark urine.',
#   'mild fever, dark urine, loss of appetite',
#   'I feel mild fever and I also feel like dark urine but I also feel like loss of appetite.',
#   'loss of appetite, yellowish skin, diarrhoea',
#   'I feel loss of appetite and I also feel like yellowish skin but I also feel like diarrhoea.',
#   'loss of appetite, vomiting, yellowish skin',
#   'I feel loss of appetite and I also feel like vomiting but I also feel like yellowish skin.',
#   'loss of appetite, abdominal pain, diarrhoea',
#   'I feel loss of appetite and I also feel like abdominal pain but I also feel like diarrhoea.',
#   'dark urine, mild fever, abdominal pain',
#   'I feel dark urine and I also feel like mild fever but I also feel like abdominal pain.',
#   'mild fever, abdominal pain, diarrhoea',
#   'I feel mild fever and I also feel like abdominal pain but I also feel like diarrhoea.',
#   'vomiting, dark urine, nausea',
#   'I feel vomiting and I also feel like dark urine but I also feel like nausea.',
#   'diarrhoea, mild fever, yellowish skin',
#   'I feel diarrhoea and I also feel like mild fever but I also feel like yellowish skin.',
#   'vomiting, loss of appetite, yellowish skin',
#   'I feel vomiting and I also feel like loss of appetite but I also feel like yellowish skin.',
#   'yellowish skin, diarrhoea, vomiting',
#   'I feel yellowish skin and I also feel like diarrhoea but I also feel like vomiting.',
#   'muscle pain, yellowish skin, joint pain',
#   'I feel muscle pain and I also feel like yellowish skin but I also feel like joint pain.',
#   'nausea, joint pain, abdominal pain',
#   'I feel nausea and I also feel like joint pain but I also feel like abdominal pain.',
#   'mild fever, diarrhoea, yellowish skin',
#   'I feel mild fever and I also feel like diarrhoea but I also feel like yellowish skin.',
#   'loss of appetite, nausea, vomiting',
#   'I feel loss of appetite and I also feel like nausea but I also feel like vomiting.',
#   'muscle pain, nausea, joint pain',
#   'I feel muscle pain and I also feel like nausea but I also feel like joint pain.',
#   'joint pain, loss of appetite, nausea',
#   'I feel joint pain and I also feel like loss of appetite but I also feel like nausea.',
#   'joint pain, vomiting, abdominal pain',
#   'I feel joint pain and I also feel like vomiting but I also feel like abdominal pain.',
#   'dark urine, mild fever, muscle pain',
#   'I feel dark urine and I also feel like mild fever but I also feel like muscle pain.',
#   'vomiting, diarrhoea, abdominal pain',
#   'I feel vomiting and I also feel like diarrhoea but I also feel like abdominal pain.',
#   'mild fever, diarrhoea, vomiting',
#   'I feel mild fever and I also feel like diarrhoea but I also feel like vomiting.',
#   'vomiting, loss of appetite, abdominal pain',
#   'I feel vomiting and I also feel like loss of appetite but I also feel like abdominal pain.',
#   'joint pain, dark urine, yellowish skin',
#   'I feel joint pain and I also feel like dark urine but I also feel like yellowish skin.',
#   'vomiting, muscle pain, abdominal pain',
#   'I feel vomiting and I also feel like muscle pain but I also feel like abdominal pain.',
#   'mild fever, loss of appetite, joint pain',
#   'I feel mild fever and I also feel like loss of appetite but I also feel like joint pain.',
#   'yellowish skin, joint pain, dark urine',
#   'I feel yellowish skin and I also feel like joint pain but I also feel like dark urine.',
#   'loss of appetite, nausea, muscle pain',
#   'I feel loss of appetite and I also feel like nausea but I also feel like muscle pain.',
#   'diarrhoea, dark urine, joint pain',
#   'I feel diarrhoea and I also feel like dark urine but I also feel like joint pain.',
#   'vomiting, diarrhoea, yellowish skin',
#   'I feel vomiting and I also feel like diarrhoea but I also feel like yellowish skin.',
#   'joint pain, vomiting, muscle pain',
#   'I feel joint pain and I also feel like vomiting but I also feel like muscle pain.',
#   'abdominal pain, dark urine, nausea',
#   'I feel abdominal pain and I also feel like dark urine but I also feel like nausea.',
#   'dark urine, vomiting, diarrhoea',
#   'I feel dark urine and I also feel like vomiting but I also feel like diarrhoea.',
#   'loss of appetite, diarrhoea, yellowish skin',
#   'I feel loss of appetite and I also feel like diarrhoea but I also feel like yellowish skin.',
#   'mild fever, nausea, yellowish skin',
#   'I feel mild fever and I also feel like nausea but I also feel like yellowish skin.',
#   'dark urine, muscle pain, loss of appetite',
#   'I feel dark urine and I also feel like muscle pain but I also feel like loss of appetite.',
#   'nausea, joint pain, mild fever',
#   'I feel nausea and I also feel like joint pain but I also feel like mild fever.',
#   'yellowish skin, loss of appetite, joint pain',
#   'I feel yellowish skin and I also feel like loss of appetite but I also feel like joint pain.',
#   'nausea, diarrhoea, dark urine',
#   'I feel nausea and I also feel like diarrhoea but I also feel like dark urine.',
#   'abdominal pain, vomiting, nausea',
#   'I feel abdominal pain and I also feel like vomiting but I also feel like nausea.',
#   'diarrhoea, yellowish skin, nausea',
#   'I feel diarrhoea and I also feel like yellowish skin but I also feel like nausea.',
#   'abdominal pain, dark urine, vomiting',
#   'I feel abdominal pain and I also feel like dark urine but I also feel like vomiting.'],
#  'Hepatitis E': ['abdominal pain, loss of appetite, vomiting',
#   'I feel abdominal pain and I also feel like loss of appetite but I also feel like vomiting.',
#   'loss of appetite, yellowing of eyes, stomach bleeding',
#   'I feel loss of appetite and I also feel like yellowing of eyes but I also feel like stomach bleeding.',
#   'loss of appetite, stomach bleeding, yellowish skin',
#   'I feel loss of appetite and I also feel like stomach bleeding but I also feel like yellowish skin.',
#   'fatigue, vomiting, yellowing of eyes',
#   'I feel fatigue and I also feel like vomiting but I also feel like yellowing of eyes.',
#   'abdominal pain, loss of appetite, nausea',
#   'I feel abdominal pain and I also feel like loss of appetite but I also feel like nausea.',
#   'dark urine, fatigue, nausea',
#   'I feel dark urine and I also feel like fatigue but I also feel like nausea.',
#   'yellowing of eyes, yellowish skin, coma',
#   'I feel yellowing of eyes and I also feel like yellowish skin but I also feel like coma.',
#   'coma, dark urine, vomiting',
#   'I feel coma and I also feel like dark urine but I also feel like vomiting.',
#   'loss of appetite, nausea, abdominal pain',
#   'I feel loss of appetite and I also feel like nausea but I also feel like abdominal pain.',
#   'fatigue, abdominal pain, yellowish skin',
#   'I feel fatigue and I also feel like abdominal pain but I also feel like yellowish skin.',
#   'abdominal pain, coma, fatigue',
#   'I feel abdominal pain and I also feel like coma but I also feel like fatigue.',
#   'vomiting, coma, abdominal pain',
#   'I feel vomiting and I also feel like coma but I also feel like abdominal pain.',
#   'acute liver failure, fatigue, vomiting',
#   'I feel acute liver failure and I also feel like fatigue but I also feel like vomiting.',
#   'stomach bleeding, fatigue, acute liver failure',
#   'I feel stomach bleeding and I also feel like fatigue but I also feel like acute liver failure.',
#   'joint pain, yellowish skin, stomach bleeding',
#   'I feel joint pain and I also feel like yellowish skin but I also feel like stomach bleeding.',
#   'dark urine, fatigue, abdominal pain',
#   'I feel dark urine and I also feel like fatigue but I also feel like abdominal pain.',
#   'vomiting, fatigue, yellowing of eyes',
#   'I feel vomiting and I also feel like fatigue but I also feel like yellowing of eyes.',
#   'yellowing of eyes, fatigue, yellowish skin',
#   'I feel yellowing of eyes and I also feel like fatigue but I also feel like yellowish skin.',
#   'coma, acute liver failure, stomach bleeding',
#   'I feel coma and I also feel like acute liver failure but I also feel like stomach bleeding.',
#   'fatigue, coma, stomach bleeding',
#   'I feel fatigue and I also feel like coma but I also feel like stomach bleeding.',
#   'coma, acute liver failure, dark urine',
#   'I feel coma and I also feel like acute liver failure but I also feel like dark urine.',
#   'joint pain, yellowish skin, coma',
#   'I feel joint pain and I also feel like yellowish skin but I also feel like coma.',
#   'acute liver failure, nausea, fatigue',
#   'I feel acute liver failure and I also feel like nausea but I also feel like fatigue.',
#   'loss of appetite, acute liver failure, nausea',
#   'I feel loss of appetite and I also feel like acute liver failure but I also feel like nausea.',
#   'stomach bleeding, fatigue, yellowish skin',
#   'I feel stomach bleeding and I also feel like fatigue but I also feel like yellowish skin.',
#   'loss of appetite, fatigue, acute liver failure',
#   'I feel loss of appetite and I also feel like fatigue but I also feel like acute liver failure.',
#   'joint pain, vomiting, acute liver failure',
#   'I feel joint pain and I also feel like vomiting but I also feel like acute liver failure.',
#   'acute liver failure, joint pain, yellowing of eyes',
#   'I feel acute liver failure and I also feel like joint pain but I also feel like yellowing of eyes.',
#   'abdominal pain, vomiting, dark urine',
#   'I feel abdominal pain and I also feel like vomiting but I also feel like dark urine.',
#   'dark urine, yellowish skin, nausea',
#   'I feel dark urine and I also feel like yellowish skin but I also feel like nausea.',
#   'acute liver failure, stomach bleeding, dark urine',
#   'I feel acute liver failure and I also feel like stomach bleeding but I also feel like dark urine.',
#   'fatigue, acute liver failure, coma',
#   'I feel fatigue and I also feel like acute liver failure but I also feel like coma.',
#   'loss of appetite, joint pain, nausea',
#   'I feel loss of appetite and I also feel like joint pain but I also feel like nausea.',
#   'yellowish skin, dark urine, joint pain',
#   'I feel yellowish skin and I also feel like dark urine but I also feel like joint pain.',
#   'nausea, yellowing of eyes, stomach bleeding',
#   'I feel nausea and I also feel like yellowing of eyes but I also feel like stomach bleeding.',
#   'fatigue, coma, acute liver failure',
#   'I feel fatigue and I also feel like coma but I also feel like acute liver failure.',
#   'acute liver failure, dark urine, yellowish skin',
#   'I feel acute liver failure and I also feel like dark urine but I also feel like yellowish skin.',
#   'yellowing of eyes, vomiting, fatigue',
#   'I feel yellowing of eyes and I also feel like vomiting but I also feel like fatigue.',
#   'loss of appetite, dark urine, stomach bleeding',
#   'I feel loss of appetite and I also feel like dark urine but I also feel like stomach bleeding.',
#   'coma, yellowish skin, nausea',
#   'I feel coma and I also feel like yellowish skin but I also feel like nausea.',
#   'yellowish skin, abdominal pain, fatigue',
#   'I feel yellowish skin and I also feel like abdominal pain but I also feel like fatigue.'],
#  'Malaria': ['vomiting, sweating, headache',
#   'I feel vomiting and I also feel like sweating but I also feel like headache.',
#   'headache, nausea, muscle pain',
#   'I feel headache and I also feel like nausea but I also feel like muscle pain.',
#   'chills, headache, muscle pain',
#   'I feel chills and I also feel like headache but I also feel like muscle pain.',
#   'muscle pain, headache, sweating',
#   'I feel muscle pain and I also feel like headache but I also feel like sweating.',
#   'diarrhoea, nausea, chills',
#   'I feel diarrhoea and I also feel like nausea but I also feel like chills.',
#   'diarrhoea, vomiting, chills',
#   'I feel diarrhoea and I also feel like vomiting but I also feel like chills.',
#   'chills, headache, diarrhoea',
#   'I feel chills and I also feel like headache but I also feel like diarrhoea.',
#   'sweating, headache, vomiting',
#   'I feel sweating and I also feel like headache but I also feel like vomiting.',
#   'chills, vomiting, nausea',
#   'I feel chills and I also feel like vomiting but I also feel like nausea.',
#   'vomiting, sweating, muscle pain',
#   'I feel vomiting and I also feel like sweating but I also feel like muscle pain.',
#   'nausea, headache, diarrhoea',
#   'I feel nausea and I also feel like headache but I also feel like diarrhoea.',
#   'sweating, nausea, headache',
#   'I feel sweating and I also feel like nausea but I also feel like headache.',
#   'diarrhoea, chills, muscle pain',
#   'I feel diarrhoea and I also feel like chills but I also feel like muscle pain.',
#   'nausea, muscle pain, chills',
#   'I feel nausea and I also feel like muscle pain but I also feel like chills.',
#   'chills, vomiting, diarrhoea',
#   'I feel chills and I also feel like vomiting but I also feel like diarrhoea.',
#   'muscle pain, headache, vomiting',
#   'I feel muscle pain and I also feel like headache but I also feel like vomiting.',
#   'chills, nausea, muscle pain',
#   'I feel chills and I also feel like nausea but I also feel like muscle pain.',
#   'diarrhoea, muscle pain, sweating',
#   'I feel diarrhoea and I also feel like muscle pain but I also feel like sweating.',
#   'muscle pain, nausea, headache',
#   'I feel muscle pain and I also feel like nausea but I also feel like headache.',
#   'vomiting, nausea, sweating',
#   'I feel vomiting and I also feel like nausea but I also feel like sweating.',
#   'diarrhoea, sweating, muscle pain',
#   'I feel diarrhoea and I also feel like sweating but I also feel like muscle pain.',
#   'diarrhoea, sweating, muscle pain',
#   'I feel diarrhoea and I also feel like sweating but I also feel like muscle pain.',
#   'sweating, nausea, muscle pain',
#   'I feel sweating and I also feel like nausea but I also feel like muscle pain.',
#   'diarrhoea, muscle pain, headache',
#   'I feel diarrhoea and I also feel like muscle pain but I also feel like headache.',
#   'sweating, nausea, vomiting',
#   'I feel sweating and I also feel like nausea but I also feel like vomiting.',
#   'diarrhoea, vomiting, nausea',
#   'I feel diarrhoea and I also feel like vomiting but I also feel like nausea.',
#   'diarrhoea, sweating, muscle pain',
#   'I feel diarrhoea and I also feel like sweating but I also feel like muscle pain.',
#   'diarrhoea, vomiting, muscle pain',
#   'I feel diarrhoea and I also feel like vomiting but I also feel like muscle pain.',
#   'muscle pain, vomiting, sweating',
#   'I feel muscle pain and I also feel like vomiting but I also feel like sweating.',
#   'diarrhoea, vomiting, headache',
#   'I feel diarrhoea and I also feel like vomiting but I also feel like headache.',
#   'diarrhoea, headache, nausea',
#   'I feel diarrhoea and I also feel like headache but I also feel like nausea.',
#   'muscle pain, nausea, diarrhoea',
#   'I feel muscle pain and I also feel like nausea but I also feel like diarrhoea.',
#   'nausea, vomiting, headache',
#   'I feel nausea and I also feel like vomiting but I also feel like headache.',
#   'muscle pain, vomiting, nausea',
#   'I feel muscle pain and I also feel like vomiting but I also feel like nausea.',
#   'vomiting, muscle pain, headache',
#   'I feel vomiting and I also feel like muscle pain but I also feel like headache.',
#   'muscle pain, nausea, vomiting',
#   'I feel muscle pain and I also feel like nausea but I also feel like vomiting.',
#   'nausea, sweating, chills',
#   'I feel nausea and I also feel like sweating but I also feel like chills.',
#   'headache, diarrhoea, chills',
#   'I feel headache and I also feel like diarrhoea but I also feel like chills.',
#   'diarrhoea, headache, chills',
#   'I feel diarrhoea and I also feel like headache but I also feel like chills.',
#   'headache, sweating, vomiting',
#   'I feel headache and I also feel like sweating but I also feel like vomiting.',
#   'diarrhoea, headache, muscle pain',
#   'I feel diarrhoea and I also feel like headache but I also feel like muscle pain.'],
#  'Arthritis': ['movement stiffness, stiff neck, painful walking',
#   'I feel movement stiffness and I also feel like stiff neck but I also feel like painful walking.',
#   'movement stiffness, painful walking, stiff neck',
#   'I feel movement stiffness and I also feel like painful walking but I also feel like stiff neck.',
#   'stiff neck, painful walking, movement stiffness',
#   'I feel stiff neck and I also feel like painful walking but I also feel like movement stiffness.',
#   'painful walking, swelling joints, stiff neck',
#   'I feel painful walking and I also feel like swelling joints but I also feel like stiff neck.',
#   'painful walking, movement stiffness, stiff neck',
#   'I feel painful walking and I also feel like movement stiffness but I also feel like stiff neck.',
#   'movement stiffness, stiff neck, painful walking',
#   'I feel movement stiffness and I also feel like stiff neck but I also feel like painful walking.',
#   'movement stiffness, painful walking, stiff neck',
#   'I feel movement stiffness and I also feel like painful walking but I also feel like stiff neck.',
#   'movement stiffness, painful walking, swelling joints',
#   'I feel movement stiffness and I also feel like painful walking but I also feel like swelling joints.',
#   'swelling joints, painful walking, movement stiffness',
#   'I feel swelling joints and I also feel like painful walking but I also feel like movement stiffness.',
#   'swelling joints, painful walking, movement stiffness',
#   'I feel swelling joints and I also feel like painful walking but I also feel like movement stiffness.',
#   'painful walking, swelling joints, movement stiffness',
#   'I feel painful walking and I also feel like swelling joints but I also feel like movement stiffness.',
#   'stiff neck, movement stiffness, swelling joints',
#   'I feel stiff neck and I also feel like movement stiffness but I also feel like swelling joints.',
#   'stiff neck, swelling joints, movement stiffness',
#   'I feel stiff neck and I also feel like swelling joints but I also feel like movement stiffness.',
#   'painful walking, movement stiffness, swelling joints',
#   'I feel painful walking and I also feel like movement stiffness but I also feel like swelling joints.',
#   'swelling joints, painful walking, movement stiffness',
#   'I feel swelling joints and I also feel like painful walking but I also feel like movement stiffness.',
#   'painful walking, swelling joints, movement stiffness',
#   'I feel painful walking and I also feel like swelling joints but I also feel like movement stiffness.',
#   'movement stiffness, swelling joints, stiff neck',
#   'I feel movement stiffness and I also feel like swelling joints but I also feel like stiff neck.',
#   'movement stiffness, swelling joints, painful walking',
#   'I feel movement stiffness and I also feel like swelling joints but I also feel like painful walking.',
#   'stiff neck, swelling joints, movement stiffness',
#   'I feel stiff neck and I also feel like swelling joints but I also feel like movement stiffness.',
#   'movement stiffness, painful walking, swelling joints',
#   'I feel movement stiffness and I also feel like painful walking but I also feel like swelling joints.',
#   'movement stiffness, painful walking, swelling joints',
#   'I feel movement stiffness and I also feel like painful walking but I also feel like swelling joints.',
#   'swelling joints, movement stiffness, stiff neck',
#   'I feel swelling joints and I also feel like movement stiffness but I also feel like stiff neck.',
#   'swelling joints, painful walking, stiff neck',
#   'I feel swelling joints and I also feel like painful walking but I also feel like stiff neck.',
#   'painful walking, movement stiffness, stiff neck',
#   'I feel painful walking and I also feel like movement stiffness but I also feel like stiff neck.',
#   'painful walking, movement stiffness, stiff neck',
#   'I feel painful walking and I also feel like movement stiffness but I also feel like stiff neck.',
#   'movement stiffness, painful walking, swelling joints',
#   'I feel movement stiffness and I also feel like painful walking but I also feel like swelling joints.',
#   'painful walking, movement stiffness, swelling joints',
#   'I feel painful walking and I also feel like movement stiffness but I also feel like swelling joints.',
#   'painful walking, movement stiffness, stiff neck',
#   'I feel painful walking and I also feel like movement stiffness but I also feel like stiff neck.',
#   'swelling joints, movement stiffness, painful walking',
#   'I feel swelling joints and I also feel like movement stiffness but I also feel like painful walking.',
#   'movement stiffness, swelling joints, painful walking',
#   'I feel movement stiffness and I also feel like swelling joints but I also feel like painful walking.',
#   'movement stiffness, swelling joints, stiff neck',
#   'I feel movement stiffness and I also feel like swelling joints but I also feel like stiff neck.',
#   'painful walking, stiff neck, swelling joints',
#   'I feel painful walking and I also feel like stiff neck but I also feel like swelling joints.',
#   'stiff neck, swelling joints, movement stiffness',
#   'I feel stiff neck and I also feel like swelling joints but I also feel like movement stiffness.',
#   'movement stiffness, swelling joints, stiff neck',
#   'I feel movement stiffness and I also feel like swelling joints but I also feel like stiff neck.',
#   'painful walking, stiff neck, movement stiffness',
#   'I feel painful walking and I also feel like stiff neck but I also feel like movement stiffness.',
#   'movement stiffness, painful walking, swelling joints',
#   'I feel movement stiffness and I also feel like painful walking but I also feel like swelling joints.',
#   'stiff neck, movement stiffness, painful walking',
#   'I feel stiff neck and I also feel like movement stiffness but I also feel like painful walking.',
#   'painful walking, stiff neck, swelling joints',
#   'I feel painful walking and I also feel like stiff neck but I also feel like swelling joints.',
#   'swelling joints, movement stiffness, painful walking',
#   'I feel swelling joints and I also feel like movement stiffness but I also feel like painful walking.',
#   'stiff neck, painful walking, movement stiffness',
#   'I feel stiff neck and I also feel like painful walking but I also feel like movement stiffness.',
#   'movement stiffness, painful walking, swelling joints',
#   'I feel movement stiffness and I also feel like painful walking but I also feel like swelling joints.'],
#  '(vertigo) Paroymsal  Positional Vertigo': ['vomiting, headache, nausea',
#   'I feel vomiting and I also feel like headache but I also feel like nausea.',
#   'vomiting, spinning movements, nausea',
#   'I feel vomiting and I also feel like spinning movements but I also feel like nausea.',
#   'unsteadiness, vomiting, nausea',
#   'I feel unsteadiness and I also feel like vomiting but I also feel like nausea.',
#   'vomiting, spinning movements, headache',
#   'I feel vomiting and I also feel like spinning movements but I also feel like headache.',
#   'unsteadiness, vomiting, spinning movements',
#   'I feel unsteadiness and I also feel like vomiting but I also feel like spinning movements.',
#   'nausea, spinning movements, vomiting',
#   'I feel nausea and I also feel like spinning movements but I also feel like vomiting.',
#   'headache, spinning movements, vomiting',
#   'I feel headache and I also feel like spinning movements but I also feel like vomiting.',
#   'spinning movements, vomiting, headache',
#   'I feel spinning movements and I also feel like vomiting but I also feel like headache.',
#   'spinning movements, nausea, headache',
#   'I feel spinning movements and I also feel like nausea but I also feel like headache.',
#   'nausea, vomiting, headache',
#   'I feel nausea and I also feel like vomiting but I also feel like headache.',
#   'nausea, spinning movements, headache',
#   'I feel nausea and I also feel like spinning movements but I also feel like headache.',
#   'headache, vomiting, spinning movements',
#   'I feel headache and I also feel like vomiting but I also feel like spinning movements.',
#   'vomiting, unsteadiness, nausea',
#   'I feel vomiting and I also feel like unsteadiness but I also feel like nausea.',
#   'vomiting, unsteadiness, nausea',
#   'I feel vomiting and I also feel like unsteadiness but I also feel like nausea.',
#   'unsteadiness, vomiting, nausea',
#   'I feel unsteadiness and I also feel like vomiting but I also feel like nausea.',
#   'vomiting, unsteadiness, spinning movements',
#   'I feel vomiting and I also feel like unsteadiness but I also feel like spinning movements.',
#   'spinning movements, nausea, vomiting',
#   'I feel spinning movements and I also feel like nausea but I also feel like vomiting.',
#   'unsteadiness, vomiting, nausea',
#   'I feel unsteadiness and I also feel like vomiting but I also feel like nausea.',
#   'headache, nausea, unsteadiness',
#   'I feel headache and I also feel like nausea but I also feel like unsteadiness.',
#   'headache, spinning movements, unsteadiness',
#   'I feel headache and I also feel like spinning movements but I also feel like unsteadiness.',
#   'spinning movements, nausea, headache',
#   'I feel spinning movements and I also feel like nausea but I also feel like headache.',
#   'unsteadiness, spinning movements, vomiting',
#   'I feel unsteadiness and I also feel like spinning movements but I also feel like vomiting.',
#   'vomiting, unsteadiness, nausea',
#   'I feel vomiting and I also feel like unsteadiness but I also feel like nausea.',
#   'spinning movements, unsteadiness, vomiting',
#   'I feel spinning movements and I also feel like unsteadiness but I also feel like vomiting.',
#   'vomiting, nausea, spinning movements',
#   'I feel vomiting and I also feel like nausea but I also feel like spinning movements.',
#   'spinning movements, headache, nausea',
#   'I feel spinning movements and I also feel like headache but I also feel like nausea.',
#   'nausea, spinning movements, vomiting',
# ...
#   'I feel altered sensorium and I also feel like headache but I also feel like weakness of one body side.',
#   'altered sensorium, weakness of one body side, headache',
#   'I feel altered sensorium and I also feel like weakness of one body side but I also feel like headache.',
#   'headache, altered sensorium, weakness of one body side',
#   'I feel headache and I also feel like altered sensorium but I also feel like weakness of one body side.',
#   'headache, altered sensorium, weakness of one body side',
#   'I feel headache and I also feel like altered sensorium but I also feel like weakness of one body side.',
#   'headache, altered sensorium, weakness of one body side',
#   'I feel headache and I also feel like altered sensorium but I also feel like weakness of one body side.',
#   'headache, weakness of one body side, altered sensorium',
#   'I feel headache and I also feel like weakness of one body side but I also feel like altered sensorium.',
#   'altered sensorium, headache, weakness of one body side',
#   'I feel altered sensorium and I also feel like headache but I also feel like weakness of one body side.',
#   'weakness of one body side, headache, altered sensorium',
#   'I feel weakness of one body side and I also feel like headache but I also feel like altered sensorium.',
#   'headache, altered sensorium, weakness of one body side',
#   'I feel headache and I also feel like altered sensorium but I also feel like weakness of one body side.',
#   'weakness of one body side, altered sensorium, headache',
#   'I feel weakness of one body side and I also feel like altered sensorium but I also feel like headache.',
#   'headache, weakness of one body side, altered sensorium',
#   'I feel headache and I also feel like weakness of one body side but I also feel like altered sensorium.',
#   'altered sensorium, weakness of one body side, headache',
#   'I feel altered sensorium and I also feel like weakness of one body side but I also feel like headache.',
#   'weakness of one body side, altered sensorium, headache',
#   'I feel weakness of one body side and I also feel like altered sensorium but I also feel like headache.',
#   'weakness of one body side, altered sensorium, headache',
#   'I feel weakness of one body side and I also feel like altered sensorium but I also feel like headache.',
#   'headache, weakness of one body side, altered sensorium',
#   'I feel headache and I also feel like weakness of one body side but I also feel like altered sensorium.',
#   'headache, altered sensorium, weakness of one body side',
#   'I feel headache and I also feel like altered sensorium but I also feel like weakness of one body side.',
#   'weakness of one body side, headache, altered sensorium',
#   'I feel weakness of one body side and I also feel like headache but I also feel like altered sensorium.',
#   'weakness of one body side, altered sensorium, headache',
#   'I feel weakness of one body side and I also feel like altered sensorium but I also feel like headache.',
#   'headache, weakness of one body side, altered sensorium',
#   'I feel headache and I also feel like weakness of one body side but I also feel like altered sensorium.',
#   'headache, altered sensorium, weakness of one body side',
#   'I feel headache and I also feel like altered sensorium but I also feel like weakness of one body side.',
#   'weakness of one body side, headache, altered sensorium',
#   'I feel weakness of one body side and I also feel like headache but I also feel like altered sensorium.',
#   'weakness of one body side, altered sensorium, headache',
#   'I feel weakness of one body side and I also feel like altered sensorium but I also feel like headache.',
#   'altered sensorium, headache, weakness of one body side',
#   'I feel altered sensorium and I also feel like headache but I also feel like weakness of one body side.',
#   'weakness of one body side, headache, altered sensorium',
#   'I feel weakness of one body side and I also feel like headache but I also feel like altered sensorium.',
#   'altered sensorium, headache, weakness of one body side',
#   'I feel altered sensorium and I also feel like headache but I also feel like weakness of one body side.'],
#  'Acne': ['pus filled pimples, blackheads, skin rash',
#   'I feel pus filled pimples and I also feel like blackheads but I also feel like skin rash.',
#   'skin rash, pus filled pimples, blackheads',
#   'I feel skin rash and I also feel like pus filled pimples but I also feel like blackheads.',
#   'skin rash, pus filled pimples, blackheads',
#   'I feel skin rash and I also feel like pus filled pimples but I also feel like blackheads.',
#   'blackheads, skin rash, pus filled pimples',
#   'I feel blackheads and I also feel like skin rash but I also feel like pus filled pimples.',
#   'blackheads, pus filled pimples, skin rash',
#   'I feel blackheads and I also feel like pus filled pimples but I also feel like skin rash.',
#   'skin rash, pus filled pimples, blackheads',
#   'I feel skin rash and I also feel like pus filled pimples but I also feel like blackheads.',
#   'blackheads, pus filled pimples, skin rash',
#   'I feel blackheads and I also feel like pus filled pimples but I also feel like skin rash.',
#   'blackheads, skin rash, pus filled pimples',
#   'I feel blackheads and I also feel like skin rash but I also feel like pus filled pimples.',
#   'blackheads, pus filled pimples, skin rash',
#   'I feel blackheads and I also feel like pus filled pimples but I also feel like skin rash.',
#   'blackheads, skin rash, pus filled pimples',
#   'I feel blackheads and I also feel like skin rash but I also feel like pus filled pimples.',
#   'blackheads, pus filled pimples, skin rash',
#   'I feel blackheads and I also feel like pus filled pimples but I also feel like skin rash.',
#   'pus filled pimples, skin rash, blackheads',
#   'I feel pus filled pimples and I also feel like skin rash but I also feel like blackheads.',
#   'pus filled pimples, blackheads, skin rash',
#   'I feel pus filled pimples and I also feel like blackheads but I also feel like skin rash.',
#   'skin rash, blackheads, pus filled pimples',
#   'I feel skin rash and I also feel like blackheads but I also feel like pus filled pimples.',
#   'pus filled pimples, blackheads, skin rash',
#   'I feel pus filled pimples and I also feel like blackheads but I also feel like skin rash.',
#   'blackheads, skin rash, pus filled pimples',
#   'I feel blackheads and I also feel like skin rash but I also feel like pus filled pimples.',
#   'skin rash, blackheads, pus filled pimples',
#   'I feel skin rash and I also feel like blackheads but I also feel like pus filled pimples.',
#   'blackheads, pus filled pimples, skin rash',
#   'I feel blackheads and I also feel like pus filled pimples but I also feel like skin rash.',
#   'blackheads, pus filled pimples, skin rash',
#   'I feel blackheads and I also feel like pus filled pimples but I also feel like skin rash.',
#   'skin rash, pus filled pimples, blackheads',
#   'I feel skin rash and I also feel like pus filled pimples but I also feel like blackheads.',
#   'blackheads, skin rash, pus filled pimples',
#   'I feel blackheads and I also feel like skin rash but I also feel like pus filled pimples.',
#   'skin rash, blackheads, pus filled pimples',
#   'I feel skin rash and I also feel like blackheads but I also feel like pus filled pimples.',
#   'skin rash, pus filled pimples, blackheads',
#   'I feel skin rash and I also feel like pus filled pimples but I also feel like blackheads.',
#   'pus filled pimples, blackheads, skin rash',
#   'I feel pus filled pimples and I also feel like blackheads but I also feel like skin rash.',
#   'skin rash, blackheads, pus filled pimples',
#   'I feel skin rash and I also feel like blackheads but I also feel like pus filled pimples.',
#   'blackheads, skin rash, pus filled pimples',
#   'I feel blackheads and I also feel like skin rash but I also feel like pus filled pimples.',
#   'pus filled pimples, skin rash, blackheads',
#   'I feel pus filled pimples and I also feel like skin rash but I also feel like blackheads.',
#   'blackheads, pus filled pimples, skin rash',
#   'I feel blackheads and I also feel like pus filled pimples but I also feel like skin rash.',
#   'pus filled pimples, skin rash, blackheads',
#   'I feel pus filled pimples and I also feel like skin rash but I also feel like blackheads.',
#   'skin rash, pus filled pimples, blackheads',
#   'I feel skin rash and I also feel like pus filled pimples but I also feel like blackheads.',
#   'skin rash, blackheads, pus filled pimples',
#   'I feel skin rash and I also feel like blackheads but I also feel like pus filled pimples.',
#   'skin rash, pus filled pimples, blackheads',
#   'I feel skin rash and I also feel like pus filled pimples but I also feel like blackheads.',
#   'blackheads, pus filled pimples, skin rash',
#   'I feel blackheads and I also feel like pus filled pimples but I also feel like skin rash.',
#   'skin rash, pus filled pimples, blackheads',
#   'I feel skin rash and I also feel like pus filled pimples but I also feel like blackheads.',
#   'blackheads, skin rash, pus filled pimples',
#   'I feel blackheads and I also feel like skin rash but I also feel like pus filled pimples.',
#   'pus filled pimples, skin rash, blackheads',
#   'I feel pus filled pimples and I also feel like skin rash but I also feel like blackheads.',
#   'skin rash, pus filled pimples, blackheads',
#   'I feel skin rash and I also feel like pus filled pimples but I also feel like blackheads.',
#   'pus filled pimples, skin rash, blackheads',
#   'I feel pus filled pimples and I also feel like skin rash but I also feel like blackheads.',
#   'skin rash, pus filled pimples, blackheads',
#   'I feel skin rash and I also feel like pus filled pimples but I also feel like blackheads.',
#   'pus filled pimples, skin rash, blackheads',
#   'I feel pus filled pimples and I also feel like skin rash but I also feel like blackheads.',
#   'skin rash, blackheads, pus filled pimples',
#   'I feel skin rash and I also feel like blackheads but I also feel like pus filled pimples.'],
#  'Hypoglycemia': ['palpitations, excessive hunger, drying and tingling lips',
#   'I feel palpitations and I also feel like excessive hunger but I also feel like drying and tingling lips.',
#   'anxiety, palpitations, irritability',
#   'I feel anxiety and I also feel like palpitations but I also feel like irritability.',
#   'slurred speech, sweating, irritability',
#   'I feel slurred speech and I also feel like sweating but I also feel like irritability.',
#   'anxiety, palpitations, drying and tingling lips',
#   'I feel anxiety and I also feel like palpitations but I also feel like drying and tingling lips.',
#   'drying and tingling lips, sweating, nausea',
#   'I feel drying and tingling lips and I also feel like sweating but I also feel like nausea.',
#   'sweating, anxiety, excessive hunger',
#   'I feel sweating and I also feel like anxiety but I also feel like excessive hunger.',
#   'drying and tingling lips, excessive hunger, blurred and distorted vision',
#   'I feel drying and tingling lips and I also feel like excessive hunger but I also feel like blurred and distorted vision.',
#   'irritability, sweating, drying and tingling lips',
#   'I feel irritability and I also feel like sweating but I also feel like drying and tingling lips.',
#   'palpitations, blurred and distorted vision, excessive hunger',
#   'I feel palpitations and I also feel like blurred and distorted vision but I also feel like excessive hunger.',
#   'slurred speech, excessive hunger, vomiting',
#   'I feel slurred speech and I also feel like excessive hunger but I also feel like vomiting.',
#   'blurred and distorted vision, fatigue, drying and tingling lips',
#   'I feel blurred and distorted vision and I also feel like fatigue but I also feel like drying and tingling lips.',
#   'irritability, drying and tingling lips, vomiting',
#   'I feel irritability and I also feel like drying and tingling lips but I also feel like vomiting.',
#   'vomiting, excessive hunger, sweating',
#   'I feel vomiting and I also feel like excessive hunger but I also feel like sweating.',
#   'nausea, anxiety, fatigue',
#   'I feel nausea and I also feel like anxiety but I also feel like fatigue.',
#   'nausea, irritability, vomiting',
#   'I feel nausea and I also feel like irritability but I also feel like vomiting.',
#   'anxiety, blurred and distorted vision, slurred speech',
#   'I feel anxiety and I also feel like blurred and distorted vision but I also feel like slurred speech.',
#   'drying and tingling lips, fatigue, anxiety',
#   'I feel drying and tingling lips and I also feel like fatigue but I also feel like anxiety.',
#   'palpitations, sweating, drying and tingling lips',
#   'I feel palpitations and I also feel like sweating but I also feel like drying and tingling lips.',
#   'irritability, vomiting, excessive hunger',
#   'I feel irritability and I also feel like vomiting but I also feel like excessive hunger.',
#   'nausea, palpitations, blurred and distorted vision',
#   'I feel nausea and I also feel like palpitations but I also feel like blurred and distorted vision.',
#   'vomiting, blurred and distorted vision, fatigue',
#   'I feel vomiting and I also feel like blurred and distorted vision but I also feel like fatigue.',
#   'anxiety, nausea, sweating',
#   'I feel anxiety and I also feel like nausea but I also feel like sweating.',
#   'irritability, slurred speech, sweating',
#   'I feel irritability and I also feel like slurred speech but I also feel like sweating.',
#   'palpitations, fatigue, slurred speech',
#   'I feel palpitations and I also feel like fatigue but I also feel like slurred speech.',
#   'irritability, anxiety, drying and tingling lips',
#   'I feel irritability and I also feel like anxiety but I also feel like drying and tingling lips.',
#   'nausea, vomiting, excessive hunger',
#   'I feel nausea and I also feel like vomiting but I also feel like excessive hunger.',
#   'slurred speech, vomiting, drying and tingling lips',
#   'I feel slurred speech and I also feel like vomiting but I also feel like drying and tingling lips.',
#   'sweating, fatigue, anxiety',
#   'I feel sweating and I also feel like fatigue but I also feel like anxiety.',
#   'nausea, sweating, slurred speech',
#   'I feel nausea and I also feel like sweating but I also feel like slurred speech.',
#   'irritability, sweating, palpitations',
#   'I feel irritability and I also feel like sweating but I also feel like palpitations.',
#   'sweating, excessive hunger, anxiety',
#   'I feel sweating and I also feel like excessive hunger but I also feel like anxiety.',
#   'fatigue, sweating, irritability',
#   'I feel fatigue and I also feel like sweating but I also feel like irritability.',
#   'blurred and distorted vision, fatigue, palpitations',
#   'I feel blurred and distorted vision and I also feel like fatigue but I also feel like palpitations.',
#   'blurred and distorted vision, anxiety, drying and tingling lips',
#   'I feel blurred and distorted vision and I also feel like anxiety but I also feel like drying and tingling lips.',
#   'palpitations, blurred and distorted vision, nausea',
#   'I feel palpitations and I also feel like blurred and distorted vision but I also feel like nausea.',
#   'nausea, irritability, drying and tingling lips',
#   'I feel nausea and I also feel like irritability but I also feel like drying and tingling lips.',
#   'palpitations, anxiety, drying and tingling lips',
#   'I feel palpitations and I also feel like anxiety but I also feel like drying and tingling lips.',
#   'fatigue, palpitations, drying and tingling lips',
#   'I feel fatigue and I also feel like palpitations but I also feel like drying and tingling lips.',
#   'palpitations, nausea, irritability',
#   'I feel palpitations and I also feel like nausea but I also feel like irritability.',
#   'anxiety, palpitations, irritability',
#   'I feel anxiety and I also feel like palpitations but I also feel like irritability.',
#   'fatigue, excessive hunger, nausea',
#   'I feel fatigue and I also feel like excessive hunger but I also feel like nausea.']}

# %%
conditions = diseaseSents.keys()

conditionSentences = {}

for condition in conditions:
    sentences = diseaseSents.get(condition)
    conditionSentences[condition] = []
    
    cleaned_sent = clean_data(sentences)
    #print(cleaned_sent)
        
    conditionSentences[condition] += cleaned_sent

# %% [markdown]
# Now that the data is cleaned, we can train a markov chain model on the data, which we can then use to generate synthetic data

# %%
def MCM(cleaned_sent, n_gram=1):
 
    markov_chain = {} #dictionary with keys for eventually calculating probability of the next move
 
    for i in range(len(cleaned_sent)-n_gram-1):
 
        curr_state, next_state = "", ""
 
        for j in range(n_gram):
 
            curr_state += cleaned_sent[i+j] + " "
            next_state += cleaned_sent[i+j+n_gram] + " "
 
        curr_state = curr_state[:-1]
        next_state = next_state[:-1]
 
        if curr_state not in markov_chain:
 
            markov_chain[curr_state] = {}
            markov_chain[curr_state][next_state] = 1
 
        else:
 
            if next_state in markov_chain[curr_state]:
 
                markov_chain[curr_state][next_state] += 1
 
            else:
                markov_chain[curr_state][next_state] = 1
   
    # calculating transition probabilities
    for curr_state, transition in markov_chain.items():
 
        total = sum(transition.values())
 
        for state, count in transition.items():
           
            markov_chain[curr_state][state] = count/total
       
    return markov_chain

# %%
conditionSentences
# Out:
# {'Gastroenteritis': ['dehydration',
#   'diarrhoea',
#   'vomiting',
#   'i',
#   'feel',
#   'dehydration',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'diarrhoea',
#   'dehydration',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'diarrhoea',
#   'dehydration',
#   'vomiting',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'diarrhoea',
#   'dehydration',
#   'vomiting',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'diarrhoea',
#   'dehydration',
#   'vomiting',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'diarrhoea',
#   'dehydration',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'dehydration',
#   'vomiting',
#   'diarrhoea',
#   'i',
#   'feel',
#   'dehydration',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'diarrhoea',
#   'vomiting',
#   'dehydration',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'diarrhoea',
#   'vomiting',
#   'dehydration',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'diarrhoea',
#   'dehydration',
#   'vomiting',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'diarrhoea',
#   'dehydration',
#   'vomiting',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'diarrhoea',
#   'dehydration',
#   'vomiting',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'diarrhoea',
#   'dehydration',
#   'vomiting',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'dehydration',
#   'diarrhoea',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'vomiting',
#   'diarrhoea',
#   'dehydration',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'dehydration',
#   'diarrhoea',
#   'vomiting',
#   'i',
#   'feel',
#   'dehydration',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'diarrhoea',
#   'dehydration',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'vomiting',
#   'dehydration',
#   'diarrhoea',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'dehydration',
#   'diarrhoea',
#   'vomiting',
#   'i',
#   'feel',
#   'dehydration',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'diarrhoea',
#   'vomiting',
#   'dehydration',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'dehydration',
#   'vomiting',
#   'diarrhoea',
#   'i',
#   'feel',
#   'dehydration',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'diarrhoea',
#   'vomiting',
#   'dehydration',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'dehydration',
#   'diarrhoea',
#   'vomiting',
#   'i',
#   'feel',
#   'dehydration',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'diarrhoea',
#   'dehydration',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'vomiting',
#   'dehydration',
#   'diarrhoea',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'dehydration',
#   'vomiting',
#   'diarrhoea',
#   'i',
#   'feel',
#   'dehydration',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'diarrhoea',
#   'dehydration',
#   'vomiting',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'diarrhoea',
#   'dehydration',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'diarrhoea',
#   'vomiting',
#   'dehydration',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'diarrhoea',
#   'vomiting',
#   'dehydration',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'diarrhoea',
#   'dehydration',
#   'vomiting',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'diarrhoea',
#   'vomiting',
#   'dehydration',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'dehydration',
#   'vomiting',
#   'diarrhoea',
#   'i',
#   'feel',
#   'dehydration',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'vomiting',
#   'dehydration',
#   'diarrhoea',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'vomiting',
#   'diarrhoea',
#   'dehydration',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'diarrhoea',
#   'vomiting',
#   'dehydration',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'diarrhoea',
#   'vomiting',
#   'dehydration',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'dehydration',
#   'vomiting',
#   'diarrhoea',
#   'i',
#   'feel',
#   'dehydration',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'dehydration',
#   'vomiting',
#   'diarrhoea',
#   'i',
#   'feel',
#   'dehydration',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'diarrhoea',
#   'dehydration',
#   'vomiting',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'dehydration',
#   'diarrhoea',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea'],
#  'GERD': ['vomiting',
#   'ulcers',
#   'on',
#   'tongue',
#   'chest',
#   'pain',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'vomiting',
#   'stomach',
#   'pain',
#   'ulcers',
#   'on',
#   'tongue',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'ulcers',
#   'on',
#   'tongue',
#   'chest',
#   'pain',
#   'vomiting',
#   'i',
#   'feel',
#   'ulcers',
#   'on',
#   'tongue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'chest',
#   'pain',
#   'acidity',
#   'stomach',
#   'pain',
#   'i',
#   'feel',
#   'chest',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'stomach',
#   'pain',
#   'acidity',
#   'chest',
#   'pain',
#   'i',
#   'feel',
#   'stomach',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'vomiting',
#   'chest',
#   'pain',
#   'ulcers',
#   'on',
#   'tongue',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'vomiting',
#   'chest',
#   'pain',
#   'stomach',
#   'pain',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'vomiting',
#   'ulcers',
#   'on',
#   'tongue',
#   'chest',
#   'pain',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'ulcers',
#   'on',
#   'tongue',
#   'acidity',
#   'vomiting',
#   'i',
#   'feel',
#   'ulcers',
#   'on',
#   'tongue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'chest',
#   'pain',
#   'stomach',
#   'pain',
#   'vomiting',
#   'i',
#   'feel',
#   'chest',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'stomach',
#   'pain',
#   'acidity',
#   'ulcers',
#   'on',
#   'tongue',
#   'i',
#   'feel',
#   'stomach',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'acidity',
#   'ulcers',
#   'on',
#   'tongue',
#   'stomach',
#   'pain',
#   'i',
#   'feel',
#   'acidity',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'vomiting',
#   'stomach',
#   'pain',
#   'ulcers',
#   'on',
#   'tongue',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'acidity',
#   'stomach',
#   'pain',
#   'vomiting',
#   'i',
#   'feel',
#   'acidity',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'ulcers',
#   'on',
#   'tongue',
#   'acidity',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'chest',
#   'pain',
#   'acidity',
#   'vomiting',
#   'i',
#   'feel',
#   'chest',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'ulcers',
#   'on',
#   'tongue',
#   'stomach',
#   'pain',
#   'vomiting',
#   'i',
#   'feel',
#   'ulcers',
#   'on',
#   'tongue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'stomach',
#   'pain',
#   'ulcers',
#   'on',
#   'tongue',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'ulcers',
#   'on',
#   'tongue',
#   'chest',
#   'pain',
#   'vomiting',
#   'i',
#   'feel',
#   'ulcers',
#   'on',
#   'tongue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'stomach',
#   'pain',
#   'chest',
#   'pain',
#   'ulcers',
#   'on',
#   'tongue',
#   'i',
#   'feel',
#   'stomach',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'acidity',
#   'chest',
#   'pain',
#   'vomiting',
#   'i',
#   'feel',
#   'acidity',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'ulcers',
#   'on',
#   'tongue',
#   'acidity',
#   'vomiting',
#   'i',
#   'feel',
#   'ulcers',
#   'on',
#   'tongue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'chest',
#   'pain',
#   'stomach',
#   'pain',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'stomach',
#   'pain',
#   'acidity',
#   'chest',
#   'pain',
#   'i',
#   'feel',
#   'stomach',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'acidity',
#   'chest',
#   'pain',
#   'ulcers',
#   'on',
#   'tongue',
#   'i',
#   'feel',
#   'acidity',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'chest',
#   'pain',
#   'stomach',
#   'pain',
#   'ulcers',
#   'on',
#   'tongue',
#   'i',
#   'feel',
#   'chest',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'chest',
#   'pain',
#   'stomach',
#   'pain',
#   'acidity',
#   'i',
#   'feel',
#   'chest',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'chest',
#   'pain',
#   'stomach',
#   'pain',
#   'ulcers',
#   'on',
#   'tongue',
#   'i',
#   'feel',
#   'chest',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'acidity',
#   'vomiting',
#   'chest',
#   'pain',
#   'i',
#   'feel',
#   'acidity',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'chest',
#   'pain',
#   'ulcers',
#   'on',
#   'tongue',
#   'acidity',
#   'i',
#   'feel',
#   'chest',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'vomiting',
#   'acidity',
#   'ulcers',
#   'on',
#   'tongue',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'ulcers',
#   'on',
#   'tongue',
#   'chest',
#   'pain',
#   'stomach',
#   'pain',
#   'i',
#   'feel',
#   'ulcers',
#   'on',
#   'tongue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'ulcers',
#   'on',
#   'tongue',
#   'acidity',
#   'stomach',
#   'pain',
#   'i',
#   'feel',
#   'ulcers',
#   'on',
#   'tongue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'acidity',
#   'stomach',
#   'pain',
#   'vomiting',
#   'i',
#   'feel',
#   'acidity',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'acidity',
#   'stomach',
#   'pain',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'stomach',
#   'pain',
#   'chest',
#   'pain',
#   'vomiting',
#   'i',
#   'feel',
#   'stomach',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'stomach',
#   'pain',
#   'ulcers',
#   'on',
#   'tongue',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'vomiting',
#   'acidity',
#   'ulcers',
#   'on',
#   'tongue',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'vomiting',
#   'ulcers',
#   'on',
#   'tongue',
#   'stomach',
#   'pain',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'acidity',
#   'vomiting',
#   'stomach',
#   'pain',
#   'i',
#   'feel',
#   'acidity',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'stomach',
#   'pain',
#   'acidity',
#   'chest',
#   'pain',
#   'i',
#   'feel',
#   'stomach',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain'],
#  'Bronchial Asthma': ['mucoid',
#   'sputum',
#   'fatigue',
#   'cough',
#   'i',
#   'feel',
#   'mucoid',
#   'sputum',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'breathlessness',
#   'cough',
#   'family',
#   'history',
#   'i',
#   'feel',
#   'breathlessness',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'breathlessness',
#   'cough',
#   'mucoid',
#   'sputum',
#   'i',
#   'feel',
#   'breathlessness',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'cough',
#   'family',
#   'history',
#   'mucoid',
#   'sputum',
#   'i',
#   'feel',
#   'cough',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'breathlessness',
#   'family',
#   'history',
#   'fatigue',
#   'i',
#   'feel',
#   'breathlessness',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'mucoid',
#   'sputum',
#   'cough',
#   'breathlessness',
#   'i',
#   'feel',
#   'mucoid',
#   'sputum',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'breathlessness',
#   'fatigue',
#   'mucoid',
#   'sputum',
#   'family',
#   'history',
#   'i',
#   'feel',
#   'fatigue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'cough',
#   'family',
#   'history',
#   'fatigue',
#   'i',
#   'feel',
#   'cough',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'family',
#   'history',
#   'cough',
#   'breathlessness',
#   'i',
#   'feel',
#   'family',
#   'history',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'breathlessness',
#   'cough',
#   'family',
#   'history',
#   'fatigue',
#   'i',
#   'feel',
#   'cough',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'breathlessness',
#   'cough',
#   'family',
#   'history',
#   'i',
#   'feel',
#   'breathlessness',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'fatigue',
#   'family',
#   'history',
#   'cough',
#   'i',
#   'feel',
#   'fatigue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'mucoid',
#   'sputum',
#   'cough',
#   'fatigue',
#   'i',
#   'feel',
#   'mucoid',
#   'sputum',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'breathlessness',
#   'mucoid',
#   'sputum',
#   'fatigue',
#   'i',
#   'feel',
#   'breathlessness',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'cough',
#   'fatigue',
#   'family',
#   'history',
#   'i',
#   'feel',
#   'cough',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'family',
#   'history',
#   'breathlessness',
#   'cough',
#   'i',
#   'feel',
#   'family',
#   'history',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'breathlessness',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'cough',
#   'fatigue',
#   'breathlessness',
#   'i',
#   'feel',
#   'cough',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'breathlessness',
#   'breathlessness',
#   'mucoid',
#   'sputum',
#   'family',
#   'history',
#   'i',
#   'feel',
#   'breathlessness',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'fatigue',
#   'breathlessness',
#   'mucoid',
#   'sputum',
#   'i',
#   'feel',
#   'fatigue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'breathlessness',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'breathlessness',
#   'mucoid',
#   'sputum',
#   'fatigue',
#   'i',
#   'feel',
#   'breathlessness',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'cough',
#   'breathlessness',
#   'family',
#   'history',
#   'i',
#   'feel',
#   'cough',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'breathlessness',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'fatigue',
#   'mucoid',
#   'sputum',
#   'cough',
#   'i',
#   'feel',
#   'fatigue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'cough',
#   'mucoid',
#   'sputum',
#   'fatigue',
#   'i',
#   'feel',
#   'cough',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'breathlessness',
#   'mucoid',
#   'sputum',
#   'family',
#   'history',
#   'i',
#   'feel',
#   'breathlessness',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'breathlessness',
#   'fatigue',
#   'family',
#   'history',
#   'i',
#   'feel',
#   'breathlessness',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'cough',
#   'family',
#   'history',
#   'mucoid',
#   'sputum',
#   'i',
#   'feel',
#   'cough',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'mucoid',
#   'sputum',
#   'breathlessness',
#   'family',
#   'history',
#   'i',
#   'feel',
#   'mucoid',
#   'sputum',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'breathlessness',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'fatigue',
#   'mucoid',
#   'sputum',
#   'cough',
#   'i',
#   'feel',
#   'fatigue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'family',
#   'history',
#   'mucoid',
#   'sputum',
#   'breathlessness',
#   'i',
#   'feel',
#   'family',
#   'history',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'breathlessness',
#   'cough',
#   'family',
#   'history',
#   'mucoid',
#   'sputum',
#   'i',
#   'feel',
#   'cough',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'family',
#   'history',
#   'cough',
#   'mucoid',
#   'sputum',
#   'i',
#   'feel',
#   'family',
#   'history',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'mucoid',
#   'sputum',
#   'family',
#   'history',
#   'breathlessness',
#   'i',
#   'feel',
#   'mucoid',
#   'sputum',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'breathlessness',
#   'fatigue',
#   'family',
#   'history',
#   'breathlessness',
#   'i',
#   'feel',
#   'fatigue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'breathlessness',
#   'mucoid',
#   'sputum',
#   'family',
#   'history',
#   'cough',
#   'i',
#   'feel',
#   'mucoid',
#   'sputum',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'cough',
#   'fatigue',
#   'family',
#   'history',
#   'i',
#   'feel',
#   'cough',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'mucoid',
#   'sputum',
#   'fatigue',
#   'cough',
#   'i',
#   'feel',
#   'mucoid',
#   'sputum',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'family',
#   'history',
#   'breathlessness',
#   'cough',
#   'i',
#   'feel',
#   'family',
#   'history',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'breathlessness',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'fatigue',
#   'mucoid',
#   'sputum',
#   'cough',
#   'i',
#   'feel',
#   'fatigue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'breathlessness',
#   'mucoid',
#   'sputum',
#   'cough',
#   'i',
#   'feel',
#   'breathlessness',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'fatigue',
#   'breathlessness',
#   'family',
#   'history',
#   'i',
#   'feel',
#   'fatigue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'breathlessness',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'breathlessness',
#   'family',
#   'history',
#   'mucoid',
#   'sputum',
#   'i',
#   'feel',
#   'breathlessness',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum'],
#  'Peptic ulcer diseae': ['loss',
#   'of',
#   'appetite',
#   'vomiting',
#   'internal',
#   'itching',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'internal',
#   'itching',
#   'vomiting',
#   'passage',
#   'of',
#   'gases',
#   'i',
#   'feel',
#   'internal',
#   'itching',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'passage',
#   'of',
#   'gases',
#   'vomiting',
#   'internal',
#   'itching',
#   'loss',
#   'of',
#   'appetite',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'internal',
#   'itching',
#   'indigestion',
#   'loss',
#   'of',
#   'appetite',
#   'i',
#   'feel',
#   'internal',
#   'itching',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'vomiting',
#   'internal',
#   'itching',
#   'loss',
#   'of',
#   'appetite',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'indigestion',
#   'loss',
#   'of',
#   'appetite',
#   'vomiting',
#   'i',
#   'feel',
#   'indigestion',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'internal',
#   'itching',
#   'vomiting',
#   'loss',
#   'of',
#   'appetite',
#   'i',
#   'feel',
#   'internal',
#   'itching',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'vomiting',
#   'loss',
#   'of',
#   'appetite',
#   'internal',
#   'itching',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'passage',
#   'of',
#   'gases',
#   'indigestion',
#   'vomiting',
#   'i',
#   'feel',
#   'passage',
#   'of',
#   'gases',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'passage',
#   'of',
#   'gases',
#   'indigestion',
#   'loss',
#   'of',
#   'appetite',
#   'i',
#   'feel',
#   'passage',
#   'of',
#   'gases',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'loss',
#   'of',
#   'appetite',
#   'vomiting',
#   'passage',
#   'of',
#   'gases',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'passage',
#   'of',
#   'gases',
#   'indigestion',
#   'passage',
#   'of',
#   'gases',
#   'internal',
#   'itching',
#   'i',
#   'feel',
#   'indigestion',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'passage',
#   'of',
#   'gases',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'vomiting',
#   'internal',
#   'itching',
#   'indigestion',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'loss',
#   'of',
#   'appetite',
#   'internal',
#   'itching',
#   'vomiting',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'loss',
#   'of',
#   'appetite',
#   'internal',
#   'itching',
#   'passage',
#   'of',
#   'gases',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'passage',
#   'of',
#   'gases',
#   'vomiting',
#   'loss',
#   'of',
#   'appetite',
#   'internal',
#   'itching',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'loss',
#   'of',
#   'appetite',
#   'internal',
#   'itching',
#   'indigestion',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'indigestion',
#   'vomiting',
#   'passage',
#   'of',
#   'gases',
#   'i',
#   'feel',
#   'indigestion',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'passage',
#   'of',
#   'gases',
#   'vomiting',
#   'passage',
#   'of',
#   'gases',
#   'loss',
#   'of',
#   'appetite',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'passage',
#   'of',
#   'gases',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'internal',
#   'itching',
#   'loss',
#   'of',
#   'appetite',
#   'indigestion',
#   'i',
#   'feel',
#   'internal',
#   'itching',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'indigestion',
#   'loss',
#   'of',
#   'appetite',
#   'passage',
#   'of',
#   'gases',
#   'i',
#   'feel',
#   'indigestion',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'passage',
#   'of',
#   'gases',
#   'passage',
#   'of',
#   'gases',
#   'vomiting',
#   'indigestion',
#   'i',
#   'feel',
#   'passage',
#   'of',
#   'gases',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'indigestion',
#   'internal',
#   'itching',
#   'vomiting',
#   'i',
#   'feel',
#   'indigestion',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'internal',
#   'itching',
#   'passage',
#   'of',
#   'gases',
#   'indigestion',
#   'i',
#   'feel',
#   'internal',
#   'itching',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'passage',
#   'of',
#   'gases',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'passage',
#   'of',
#   'gases',
#   'indigestion',
#   'internal',
#   'itching',
#   'i',
#   'feel',
#   'passage',
#   'of',
#   'gases',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'loss',
#   'of',
#   'appetite',
#   'passage',
#   'of',
#   'gases',
#   'internal',
#   'itching',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'passage',
#   'of',
#   'gases',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'vomiting',
#   'indigestion',
#   'passage',
#   'of',
#   'gases',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'passage',
#   'of',
#   'gases',
#   'passage',
#   'of',
#   'gases',
#   'indigestion',
#   'loss',
#   'of',
#   'appetite',
#   'i',
#   'feel',
#   'passage',
#   'of',
#   'gases',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'loss',
#   'of',
#   'appetite',
#   'indigestion',
#   'internal',
#   'itching',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'indigestion',
#   'passage',
#   'of',
#   'gases',
#   'vomiting',
#   'i',
#   'feel',
#   'indigestion',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'passage',
#   'of',
#   'gases',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'loss',
#   'of',
#   'appetite',
#   'indigestion',
#   'internal',
#   'itching',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'loss',
#   'of',
#   'appetite',
#   'vomiting',
#   'internal',
#   'itching',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'indigestion',
#   'loss',
#   'of',
#   'appetite',
#   'internal',
#   'itching',
#   'i',
#   'feel',
#   'indigestion',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'indigestion',
#   'internal',
#   'itching',
#   'vomiting',
#   'i',
#   'feel',
#   'indigestion',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'indigestion',
#   'loss',
#   'of',
#   'appetite',
#   'internal',
#   'itching',
#   'i',
#   'feel',
#   'indigestion',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'loss',
#   'of',
#   'appetite',
#   'vomiting',
#   'passage',
#   'of',
#   'gases',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'passage',
#   'of',
#   'gases',
#   'vomiting',
#   'internal',
#   'itching',
#   'passage',
#   'of',
#   'gases',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'passage',
#   'of',
#   'gases',
#   'vomiting',
#   'internal',
#   'itching',
#   'indigestion',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'loss',
#   'of',
#   'appetite',
#   'internal',
#   'itching',
#   'indigestion',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'loss',
#   'of',
#   'appetite',
#   'indigestion',
#   'internal',
#   'itching',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'loss',
#   'of',
#   'appetite',
#   'vomiting',
#   'internal',
#   'itching',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching'],
#  'hepatitis A': ['abdominal',
#   'pain',
#   'vomiting',
#   'dark',
#   'urine',
#   'i',
#   'feel',
#   'abdominal',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dark',
#   'urine',
#   'mild',
#   'fever',
#   'dark',
#   'urine',
#   'loss',
#   'of',
#   'appetite',
#   'i',
#   'feel',
#   'mild',
#   'fever',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dark',
#   'urine',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'loss',
#   'of',
#   'appetite',
#   'yellowish',
#   'skin',
#   'diarrhoea',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowish',
#   'skin',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'loss',
#   'of',
#   'appetite',
#   'vomiting',
#   'yellowish',
#   'skin',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowish',
#   'skin',
#   'loss',
#   'of',
#   'appetite',
#   'abdominal',
#   'pain',
#   'diarrhoea',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'abdominal',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'dark',
#   'urine',
#   'mild',
#   'fever',
#   'abdominal',
#   'pain',
#   'i',
#   'feel',
#   'dark',
#   'urine',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mild',
#   'fever',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'abdominal',
#   'pain',
#   'mild',
#   'fever',
#   'abdominal',
#   'pain',
#   'diarrhoea',
#   'i',
#   'feel',
#   'mild',
#   'fever',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'abdominal',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'vomiting',
#   'dark',
#   'urine',
#   'nausea',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dark',
#   'urine',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea',
#   'diarrhoea',
#   'mild',
#   'fever',
#   'yellowish',
#   'skin',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mild',
#   'fever',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowish',
#   'skin',
#   'vomiting',
#   'loss',
#   'of',
#   'appetite',
#   'yellowish',
#   'skin',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowish',
#   'skin',
#   'yellowish',
#   'skin',
#   'diarrhoea',
#   'vomiting',
#   'i',
#   'feel',
#   'yellowish',
#   'skin',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'muscle',
#   'pain',
#   'yellowish',
#   'skin',
#   'joint',
#   'pain',
#   'i',
#   'feel',
#   'muscle',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowish',
#   'skin',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'joint',
#   'pain',
#   'nausea',
#   'joint',
#   'pain',
#   'abdominal',
#   'pain',
#   'i',
#   'feel',
#   'nausea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'joint',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'abdominal',
#   'pain',
#   'mild',
#   'fever',
#   'diarrhoea',
#   'yellowish',
#   'skin',
#   'i',
#   'feel',
#   'mild',
#   'fever',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowish',
#   'skin',
#   'loss',
#   'of',
#   'appetite',
#   'nausea',
#   'vomiting',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'muscle',
#   'pain',
#   'nausea',
#   'joint',
#   'pain',
#   'i',
#   'feel',
#   'muscle',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'joint',
#   'pain',
#   'joint',
#   'pain',
#   'loss',
#   'of',
#   'appetite',
#   'nausea',
#   'i',
#   'feel',
#   'joint',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea',
#   'joint',
#   'pain',
#   'vomiting',
#   'abdominal',
#   'pain',
#   'i',
#   'feel',
#   'joint',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'abdominal',
#   'pain',
#   'dark',
#   'urine',
#   'mild',
#   'fever',
#   'muscle',
#   'pain',
#   'i',
#   'feel',
#   'dark',
#   'urine',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mild',
#   'fever',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'muscle',
#   'pain',
#   'vomiting',
#   'diarrhoea',
#   'abdominal',
#   'pain',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'abdominal',
#   'pain',
#   'mild',
#   'fever',
#   'diarrhoea',
#   'vomiting',
#   'i',
#   'feel',
#   'mild',
#   'fever',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'loss',
#   'of',
#   'appetite',
#   'abdominal',
#   'pain',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'abdominal',
#   'pain',
#   'joint',
#   'pain',
#   'dark',
#   'urine',
#   'yellowish',
#   'skin',
#   'i',
#   'feel',
#   'joint',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dark',
#   'urine',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowish',
#   'skin',
#   'vomiting',
#   'muscle',
#   'pain',
#   'abdominal',
#   'pain',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'muscle',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'abdominal',
#   'pain',
#   'mild',
#   'fever',
#   'loss',
#   'of',
#   'appetite',
#   'joint',
#   'pain',
#   'i',
#   'feel',
#   'mild',
#   'fever',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'joint',
#   'pain',
#   'yellowish',
#   'skin',
#   'joint',
#   'pain',
#   'dark',
#   'urine',
#   'i',
#   'feel',
#   'yellowish',
#   'skin',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'joint',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dark',
#   'urine',
#   'loss',
#   'of',
#   'appetite',
#   'nausea',
#   'muscle',
#   'pain',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'muscle',
#   'pain',
#   'diarrhoea',
#   'dark',
#   'urine',
#   'joint',
#   'pain',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dark',
#   'urine',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'joint',
#   'pain',
#   'vomiting',
#   'diarrhoea',
#   'yellowish',
#   'skin',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowish',
#   'skin',
#   'joint',
#   'pain',
#   'vomiting',
#   'muscle',
#   'pain',
#   'i',
#   'feel',
#   'joint',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'muscle',
#   'pain',
#   'abdominal',
#   'pain',
#   'dark',
#   'urine',
#   'nausea',
#   'i',
#   'feel',
#   'abdominal',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dark',
#   'urine',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea',
#   'dark',
#   'urine',
#   'vomiting',
#   'diarrhoea',
#   'i',
#   'feel',
#   'dark',
#   'urine',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'loss',
#   'of',
#   'appetite',
#   'diarrhoea',
#   'yellowish',
#   'skin',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowish',
#   'skin',
#   'mild',
#   'fever',
#   'nausea',
#   'yellowish',
#   'skin',
#   'i',
#   'feel',
#   'mild',
#   'fever',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowish',
#   'skin',
#   'dark',
#   'urine',
#   'muscle',
#   'pain',
#   'loss',
#   'of',
#   'appetite',
#   'i',
#   'feel',
#   'dark',
#   'urine',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'muscle',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'nausea',
#   'joint',
#   'pain',
#   'mild',
#   'fever',
#   'i',
#   'feel',
#   'nausea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'joint',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mild',
#   'fever',
#   'yellowish',
#   'skin',
#   'loss',
#   'of',
#   'appetite',
#   'joint',
#   'pain',
#   'i',
#   'feel',
#   'yellowish',
#   'skin',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'joint',
#   'pain',
#   'nausea',
#   'diarrhoea',
#   'dark',
#   'urine',
#   'i',
#   'feel',
#   'nausea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dark',
#   'urine',
#   'abdominal',
#   'pain',
#   'vomiting',
#   'nausea',
#   'i',
#   'feel',
#   'abdominal',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea',
#   'diarrhoea',
#   'yellowish',
#   'skin',
#   'nausea',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowish',
#   'skin',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea',
#   'abdominal',
#   'pain',
#   'dark',
#   'urine',
#   'vomiting',
#   'i',
#   'feel',
#   'abdominal',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dark',
#   'urine',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting'],
#  'Hepatitis E': ['abdominal',
#   'pain',
#   'loss',
#   'of',
#   'appetite',
#   'vomiting',
#   'i',
#   'feel',
#   'abdominal',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'loss',
#   'of',
#   'appetite',
#   'yellowing',
#   'of',
#   'eyes',
#   'stomach',
#   'bleeding',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowing',
#   'of',
#   'eyes',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'bleeding',
#   'loss',
#   'of',
#   'appetite',
#   'stomach',
#   'bleeding',
#   'yellowish',
#   'skin',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'bleeding',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowish',
#   'skin',
#   'fatigue',
#   'vomiting',
#   'yellowing',
#   'of',
#   'eyes',
#   'i',
#   'feel',
#   'fatigue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowing',
#   'of',
# ...
#   'pus',
#   'filled',
#   'pimples',
#   'skin',
#   'rash',
#   'i',
#   'feel',
#   'blackheads',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'skin',
#   'rash',
#   'blackheads',
#   'pus',
#   'filled',
#   'pimples',
#   'skin',
#   'rash',
#   'i',
#   'feel',
#   'blackheads',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'skin',
#   'rash',
#   'skin',
#   'rash',
#   'pus',
#   'filled',
#   'pimples',
#   'blackheads',
#   'i',
#   'feel',
#   'skin',
#   'rash',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'blackheads',
#   'skin',
#   'rash',
#   'pus',
#   'filled',
#   'pimples',
#   'i',
#   'feel',
#   'blackheads',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'skin',
#   'rash',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'skin',
#   'rash',
#   'blackheads',
#   'pus',
#   'filled',
#   'pimples',
#   'i',
#   'feel',
#   'skin',
#   'rash',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'skin',
#   'rash',
#   'pus',
#   'filled',
#   'pimples',
#   'blackheads',
#   'i',
#   'feel',
#   'skin',
#   'rash',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'pus',
#   'filled',
#   'pimples',
#   'blackheads',
#   'skin',
#   'rash',
#   'i',
#   'feel',
#   'pus',
#   'filled',
#   'pimples',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'skin',
#   'rash',
#   'skin',
#   'rash',
#   'blackheads',
#   'pus',
#   'filled',
#   'pimples',
#   'i',
#   'feel',
#   'skin',
#   'rash',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'blackheads',
#   'skin',
#   'rash',
#   'pus',
#   'filled',
#   'pimples',
#   'i',
#   'feel',
#   'blackheads',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'skin',
#   'rash',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'pus',
#   'filled',
#   'pimples',
#   'skin',
#   'rash',
#   'blackheads',
#   'i',
#   'feel',
#   'pus',
#   'filled',
#   'pimples',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'skin',
#   'rash',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'blackheads',
#   'pus',
#   'filled',
#   'pimples',
#   'skin',
#   'rash',
#   'i',
#   'feel',
#   'blackheads',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'skin',
#   'rash',
#   'pus',
#   'filled',
#   'pimples',
#   'skin',
#   'rash',
#   'blackheads',
#   'i',
#   'feel',
#   'pus',
#   'filled',
#   'pimples',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'skin',
#   'rash',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'skin',
#   'rash',
#   'pus',
#   'filled',
#   'pimples',
#   'blackheads',
#   'i',
#   'feel',
#   'skin',
#   'rash',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'skin',
#   'rash',
#   'blackheads',
#   'pus',
#   'filled',
#   'pimples',
#   'i',
#   'feel',
#   'skin',
#   'rash',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'skin',
#   'rash',
#   'pus',
#   'filled',
#   'pimples',
#   'blackheads',
#   'i',
#   'feel',
#   'skin',
#   'rash',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'blackheads',
#   'pus',
#   'filled',
#   'pimples',
#   'skin',
#   'rash',
#   'i',
#   'feel',
#   'blackheads',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'skin',
#   'rash',
#   'skin',
#   'rash',
#   'pus',
#   'filled',
#   'pimples',
#   'blackheads',
#   'i',
#   'feel',
#   'skin',
#   'rash',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'blackheads',
#   'skin',
#   'rash',
#   'pus',
#   'filled',
#   'pimples',
#   'i',
#   'feel',
#   'blackheads',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'skin',
#   'rash',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'pus',
#   'filled',
#   'pimples',
#   'skin',
#   'rash',
#   'blackheads',
#   'i',
#   'feel',
#   'pus',
#   'filled',
#   'pimples',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'skin',
#   'rash',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'skin',
#   'rash',
#   'pus',
#   'filled',
#   'pimples',
#   'blackheads',
#   'i',
#   'feel',
#   'skin',
#   'rash',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'pus',
#   'filled',
#   'pimples',
#   'skin',
#   'rash',
#   'blackheads',
#   'i',
#   'feel',
#   'pus',
#   'filled',
#   'pimples',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'skin',
#   'rash',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'skin',
#   'rash',
#   'pus',
#   'filled',
#   'pimples',
#   'blackheads',
#   'i',
#   'feel',
#   'skin',
#   'rash',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'pus',
#   'filled',
#   'pimples',
#   'skin',
#   'rash',
#   'blackheads',
#   'i',
#   'feel',
#   'pus',
#   'filled',
#   'pimples',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'skin',
#   'rash',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'skin',
#   'rash',
#   'blackheads',
#   'pus',
#   'filled',
#   'pimples',
#   'i',
#   'feel',
#   'skin',
#   'rash',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples'],
#  'Hypoglycemia': ['palpitations',
#   'excessive',
#   'hunger',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'i',
#   'feel',
#   'palpitations',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'excessive',
#   'hunger',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'anxiety',
#   'palpitations',
#   'irritability',
#   'i',
#   'feel',
#   'anxiety',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'palpitations',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'irritability',
#   'slurred',
#   'speech',
#   'sweating',
#   'irritability',
#   'i',
#   'feel',
#   'slurred',
#   'speech',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'sweating',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'irritability',
#   'anxiety',
#   'palpitations',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'i',
#   'feel',
#   'anxiety',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'palpitations',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'sweating',
#   'nausea',
#   'i',
#   'feel',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'sweating',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea',
#   'sweating',
#   'anxiety',
#   'excessive',
#   'hunger',
#   'i',
#   'feel',
#   'sweating',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'anxiety',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'excessive',
#   'hunger',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'excessive',
#   'hunger',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'i',
#   'feel',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'excessive',
#   'hunger',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'irritability',
#   'sweating',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'i',
#   'feel',
#   'irritability',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'sweating',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'palpitations',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'excessive',
#   'hunger',
#   'i',
#   'feel',
#   'palpitations',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'excessive',
#   'hunger',
#   'slurred',
#   'speech',
#   'excessive',
#   'hunger',
#   'vomiting',
#   'i',
#   'feel',
#   'slurred',
#   'speech',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'excessive',
#   'hunger',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'fatigue',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'i',
#   'feel',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'irritability',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'vomiting',
#   'i',
#   'feel',
#   'irritability',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'excessive',
#   'hunger',
#   'sweating',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'excessive',
#   'hunger',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'sweating',
#   'nausea',
#   'anxiety',
#   'fatigue',
#   'i',
#   'feel',
#   'nausea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'anxiety',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'nausea',
#   'irritability',
#   'vomiting',
#   'i',
#   'feel',
#   'nausea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'irritability',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'anxiety',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'slurred',
#   'speech',
#   'i',
#   'feel',
#   'anxiety',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'slurred',
#   'speech',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'fatigue',
#   'anxiety',
#   'i',
#   'feel',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'anxiety',
#   'palpitations',
#   'sweating',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'i',
#   'feel',
#   'palpitations',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'sweating',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'irritability',
#   'vomiting',
#   'excessive',
#   'hunger',
#   'i',
#   'feel',
#   'irritability',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'excessive',
#   'hunger',
#   'nausea',
#   'palpitations',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'i',
#   'feel',
#   'nausea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'palpitations',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'vomiting',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'fatigue',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'anxiety',
#   'nausea',
#   'sweating',
#   'i',
#   'feel',
#   'anxiety',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'sweating',
#   'irritability',
#   'slurred',
#   'speech',
#   'sweating',
#   'i',
#   'feel',
#   'irritability',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'slurred',
#   'speech',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'sweating',
#   'palpitations',
#   'fatigue',
#   'slurred',
#   'speech',
#   'i',
#   'feel',
#   'palpitations',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'slurred',
#   'speech',
#   'irritability',
#   'anxiety',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'i',
#   'feel',
#   'irritability',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'anxiety',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'nausea',
#   'vomiting',
#   'excessive',
#   'hunger',
#   'i',
#   'feel',
#   'nausea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'excessive',
#   'hunger',
#   'slurred',
#   'speech',
#   'vomiting',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'i',
#   'feel',
#   'slurred',
#   'speech',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'sweating',
#   'fatigue',
#   'anxiety',
#   'i',
#   'feel',
#   'sweating',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'anxiety',
#   'nausea',
#   'sweating',
#   'slurred',
#   'speech',
#   'i',
#   'feel',
#   'nausea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'sweating',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'slurred',
#   'speech',
#   'irritability',
#   'sweating',
#   'palpitations',
#   'i',
#   'feel',
#   'irritability',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'sweating',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'palpitations',
#   'sweating',
#   'excessive',
#   'hunger',
#   'anxiety',
#   'i',
#   'feel',
#   'sweating',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'excessive',
#   'hunger',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'anxiety',
#   'fatigue',
#   'sweating',
#   'irritability',
#   'i',
#   'feel',
#   'fatigue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'sweating',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'irritability',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'fatigue',
#   'palpitations',
#   'i',
#   'feel',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'palpitations',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'anxiety',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'i',
#   'feel',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'anxiety',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'palpitations',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'nausea',
#   'i',
#   'feel',
#   'palpitations',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea',
#   'nausea',
#   'irritability',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'i',
#   'feel',
#   'nausea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'irritability',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'palpitations',
#   'anxiety',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'i',
#   'feel',
#   'palpitations',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'anxiety',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'fatigue',
#   'palpitations',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'i',
#   'feel',
#   'fatigue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'palpitations',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'palpitations',
#   'nausea',
#   'irritability',
#   'i',
#   'feel',
#   'palpitations',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'irritability',
#   'anxiety',
#   'palpitations',
#   'irritability',
#   'i',
#   'feel',
#   'anxiety',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'palpitations',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'irritability',
#   'fatigue',
#   'excessive',
#   'hunger',
#   'nausea',
#   'i',
#   'feel',
#   'fatigue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'excessive',
#   'hunger',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea']}

# %%
def train_MCM(dOC=conditionSentences):
    mcmConditions = {}
    
    conditions = list(dOC.keys())

    for condition in conditions:
        sents = (dOC.get(condition))

        model = MCM(sents)
        #print(model.keys())
        states = model.keys()
        modelVals = {}

        for state in list(states):
            modelVals[state] = model.get(state)

        mcmConditions[condition] = modelVals

    return mcmConditions

# %%
mcms = train_MCM()

# %%
conditionSentences
# Out:
# {'Gastroenteritis': ['dehydration',
#   'diarrhoea',
#   'vomiting',
#   'i',
#   'feel',
#   'dehydration',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'diarrhoea',
#   'dehydration',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'diarrhoea',
#   'dehydration',
#   'vomiting',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'diarrhoea',
#   'dehydration',
#   'vomiting',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'diarrhoea',
#   'dehydration',
#   'vomiting',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'diarrhoea',
#   'dehydration',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'dehydration',
#   'vomiting',
#   'diarrhoea',
#   'i',
#   'feel',
#   'dehydration',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'diarrhoea',
#   'vomiting',
#   'dehydration',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'diarrhoea',
#   'vomiting',
#   'dehydration',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'diarrhoea',
#   'dehydration',
#   'vomiting',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'diarrhoea',
#   'dehydration',
#   'vomiting',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'diarrhoea',
#   'dehydration',
#   'vomiting',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'diarrhoea',
#   'dehydration',
#   'vomiting',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'dehydration',
#   'diarrhoea',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'vomiting',
#   'diarrhoea',
#   'dehydration',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'dehydration',
#   'diarrhoea',
#   'vomiting',
#   'i',
#   'feel',
#   'dehydration',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'diarrhoea',
#   'dehydration',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'vomiting',
#   'dehydration',
#   'diarrhoea',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'dehydration',
#   'diarrhoea',
#   'vomiting',
#   'i',
#   'feel',
#   'dehydration',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'diarrhoea',
#   'vomiting',
#   'dehydration',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'dehydration',
#   'vomiting',
#   'diarrhoea',
#   'i',
#   'feel',
#   'dehydration',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'diarrhoea',
#   'vomiting',
#   'dehydration',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'dehydration',
#   'diarrhoea',
#   'vomiting',
#   'i',
#   'feel',
#   'dehydration',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'diarrhoea',
#   'dehydration',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'vomiting',
#   'dehydration',
#   'diarrhoea',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'dehydration',
#   'vomiting',
#   'diarrhoea',
#   'i',
#   'feel',
#   'dehydration',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'diarrhoea',
#   'dehydration',
#   'vomiting',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'diarrhoea',
#   'dehydration',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'diarrhoea',
#   'vomiting',
#   'dehydration',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'diarrhoea',
#   'vomiting',
#   'dehydration',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'diarrhoea',
#   'dehydration',
#   'vomiting',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'diarrhoea',
#   'vomiting',
#   'dehydration',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'dehydration',
#   'vomiting',
#   'diarrhoea',
#   'i',
#   'feel',
#   'dehydration',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'vomiting',
#   'dehydration',
#   'diarrhoea',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'vomiting',
#   'diarrhoea',
#   'dehydration',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'diarrhoea',
#   'vomiting',
#   'dehydration',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'diarrhoea',
#   'vomiting',
#   'dehydration',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'dehydration',
#   'vomiting',
#   'diarrhoea',
#   'i',
#   'feel',
#   'dehydration',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'dehydration',
#   'vomiting',
#   'diarrhoea',
#   'i',
#   'feel',
#   'dehydration',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'diarrhoea',
#   'dehydration',
#   'vomiting',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'dehydration',
#   'diarrhoea',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dehydration',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea'],
#  'GERD': ['vomiting',
#   'ulcers',
#   'on',
#   'tongue',
#   'chest',
#   'pain',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'vomiting',
#   'stomach',
#   'pain',
#   'ulcers',
#   'on',
#   'tongue',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'ulcers',
#   'on',
#   'tongue',
#   'chest',
#   'pain',
#   'vomiting',
#   'i',
#   'feel',
#   'ulcers',
#   'on',
#   'tongue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'chest',
#   'pain',
#   'acidity',
#   'stomach',
#   'pain',
#   'i',
#   'feel',
#   'chest',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'stomach',
#   'pain',
#   'acidity',
#   'chest',
#   'pain',
#   'i',
#   'feel',
#   'stomach',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'vomiting',
#   'chest',
#   'pain',
#   'ulcers',
#   'on',
#   'tongue',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'vomiting',
#   'chest',
#   'pain',
#   'stomach',
#   'pain',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'vomiting',
#   'ulcers',
#   'on',
#   'tongue',
#   'chest',
#   'pain',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'ulcers',
#   'on',
#   'tongue',
#   'acidity',
#   'vomiting',
#   'i',
#   'feel',
#   'ulcers',
#   'on',
#   'tongue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'chest',
#   'pain',
#   'stomach',
#   'pain',
#   'vomiting',
#   'i',
#   'feel',
#   'chest',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'stomach',
#   'pain',
#   'acidity',
#   'ulcers',
#   'on',
#   'tongue',
#   'i',
#   'feel',
#   'stomach',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'acidity',
#   'ulcers',
#   'on',
#   'tongue',
#   'stomach',
#   'pain',
#   'i',
#   'feel',
#   'acidity',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'vomiting',
#   'stomach',
#   'pain',
#   'ulcers',
#   'on',
#   'tongue',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'acidity',
#   'stomach',
#   'pain',
#   'vomiting',
#   'i',
#   'feel',
#   'acidity',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'ulcers',
#   'on',
#   'tongue',
#   'acidity',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'chest',
#   'pain',
#   'acidity',
#   'vomiting',
#   'i',
#   'feel',
#   'chest',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'ulcers',
#   'on',
#   'tongue',
#   'stomach',
#   'pain',
#   'vomiting',
#   'i',
#   'feel',
#   'ulcers',
#   'on',
#   'tongue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'stomach',
#   'pain',
#   'ulcers',
#   'on',
#   'tongue',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'ulcers',
#   'on',
#   'tongue',
#   'chest',
#   'pain',
#   'vomiting',
#   'i',
#   'feel',
#   'ulcers',
#   'on',
#   'tongue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'stomach',
#   'pain',
#   'chest',
#   'pain',
#   'ulcers',
#   'on',
#   'tongue',
#   'i',
#   'feel',
#   'stomach',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'acidity',
#   'chest',
#   'pain',
#   'vomiting',
#   'i',
#   'feel',
#   'acidity',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'ulcers',
#   'on',
#   'tongue',
#   'acidity',
#   'vomiting',
#   'i',
#   'feel',
#   'ulcers',
#   'on',
#   'tongue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'chest',
#   'pain',
#   'stomach',
#   'pain',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'stomach',
#   'pain',
#   'acidity',
#   'chest',
#   'pain',
#   'i',
#   'feel',
#   'stomach',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'acidity',
#   'chest',
#   'pain',
#   'ulcers',
#   'on',
#   'tongue',
#   'i',
#   'feel',
#   'acidity',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'chest',
#   'pain',
#   'stomach',
#   'pain',
#   'ulcers',
#   'on',
#   'tongue',
#   'i',
#   'feel',
#   'chest',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'chest',
#   'pain',
#   'stomach',
#   'pain',
#   'acidity',
#   'i',
#   'feel',
#   'chest',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'chest',
#   'pain',
#   'stomach',
#   'pain',
#   'ulcers',
#   'on',
#   'tongue',
#   'i',
#   'feel',
#   'chest',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'acidity',
#   'vomiting',
#   'chest',
#   'pain',
#   'i',
#   'feel',
#   'acidity',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'chest',
#   'pain',
#   'ulcers',
#   'on',
#   'tongue',
#   'acidity',
#   'i',
#   'feel',
#   'chest',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'vomiting',
#   'acidity',
#   'ulcers',
#   'on',
#   'tongue',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'ulcers',
#   'on',
#   'tongue',
#   'chest',
#   'pain',
#   'stomach',
#   'pain',
#   'i',
#   'feel',
#   'ulcers',
#   'on',
#   'tongue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'ulcers',
#   'on',
#   'tongue',
#   'acidity',
#   'stomach',
#   'pain',
#   'i',
#   'feel',
#   'ulcers',
#   'on',
#   'tongue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'acidity',
#   'stomach',
#   'pain',
#   'vomiting',
#   'i',
#   'feel',
#   'acidity',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'acidity',
#   'stomach',
#   'pain',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'stomach',
#   'pain',
#   'chest',
#   'pain',
#   'vomiting',
#   'i',
#   'feel',
#   'stomach',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'stomach',
#   'pain',
#   'ulcers',
#   'on',
#   'tongue',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'vomiting',
#   'acidity',
#   'ulcers',
#   'on',
#   'tongue',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'vomiting',
#   'ulcers',
#   'on',
#   'tongue',
#   'stomach',
#   'pain',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'ulcers',
#   'on',
#   'tongue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'acidity',
#   'vomiting',
#   'stomach',
#   'pain',
#   'i',
#   'feel',
#   'acidity',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'pain',
#   'stomach',
#   'pain',
#   'acidity',
#   'chest',
#   'pain',
#   'i',
#   'feel',
#   'stomach',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'acidity',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'chest',
#   'pain'],
#  'Bronchial Asthma': ['mucoid',
#   'sputum',
#   'fatigue',
#   'cough',
#   'i',
#   'feel',
#   'mucoid',
#   'sputum',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'breathlessness',
#   'cough',
#   'family',
#   'history',
#   'i',
#   'feel',
#   'breathlessness',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'breathlessness',
#   'cough',
#   'mucoid',
#   'sputum',
#   'i',
#   'feel',
#   'breathlessness',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'cough',
#   'family',
#   'history',
#   'mucoid',
#   'sputum',
#   'i',
#   'feel',
#   'cough',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'breathlessness',
#   'family',
#   'history',
#   'fatigue',
#   'i',
#   'feel',
#   'breathlessness',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'mucoid',
#   'sputum',
#   'cough',
#   'breathlessness',
#   'i',
#   'feel',
#   'mucoid',
#   'sputum',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'breathlessness',
#   'fatigue',
#   'mucoid',
#   'sputum',
#   'family',
#   'history',
#   'i',
#   'feel',
#   'fatigue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'cough',
#   'family',
#   'history',
#   'fatigue',
#   'i',
#   'feel',
#   'cough',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'family',
#   'history',
#   'cough',
#   'breathlessness',
#   'i',
#   'feel',
#   'family',
#   'history',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'breathlessness',
#   'cough',
#   'family',
#   'history',
#   'fatigue',
#   'i',
#   'feel',
#   'cough',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'breathlessness',
#   'cough',
#   'family',
#   'history',
#   'i',
#   'feel',
#   'breathlessness',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'fatigue',
#   'family',
#   'history',
#   'cough',
#   'i',
#   'feel',
#   'fatigue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'mucoid',
#   'sputum',
#   'cough',
#   'fatigue',
#   'i',
#   'feel',
#   'mucoid',
#   'sputum',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'breathlessness',
#   'mucoid',
#   'sputum',
#   'fatigue',
#   'i',
#   'feel',
#   'breathlessness',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'cough',
#   'fatigue',
#   'family',
#   'history',
#   'i',
#   'feel',
#   'cough',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'family',
#   'history',
#   'breathlessness',
#   'cough',
#   'i',
#   'feel',
#   'family',
#   'history',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'breathlessness',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'cough',
#   'fatigue',
#   'breathlessness',
#   'i',
#   'feel',
#   'cough',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'breathlessness',
#   'breathlessness',
#   'mucoid',
#   'sputum',
#   'family',
#   'history',
#   'i',
#   'feel',
#   'breathlessness',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'fatigue',
#   'breathlessness',
#   'mucoid',
#   'sputum',
#   'i',
#   'feel',
#   'fatigue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'breathlessness',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'breathlessness',
#   'mucoid',
#   'sputum',
#   'fatigue',
#   'i',
#   'feel',
#   'breathlessness',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'cough',
#   'breathlessness',
#   'family',
#   'history',
#   'i',
#   'feel',
#   'cough',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'breathlessness',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'fatigue',
#   'mucoid',
#   'sputum',
#   'cough',
#   'i',
#   'feel',
#   'fatigue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'cough',
#   'mucoid',
#   'sputum',
#   'fatigue',
#   'i',
#   'feel',
#   'cough',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'breathlessness',
#   'mucoid',
#   'sputum',
#   'family',
#   'history',
#   'i',
#   'feel',
#   'breathlessness',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'breathlessness',
#   'fatigue',
#   'family',
#   'history',
#   'i',
#   'feel',
#   'breathlessness',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'cough',
#   'family',
#   'history',
#   'mucoid',
#   'sputum',
#   'i',
#   'feel',
#   'cough',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'mucoid',
#   'sputum',
#   'breathlessness',
#   'family',
#   'history',
#   'i',
#   'feel',
#   'mucoid',
#   'sputum',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'breathlessness',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'fatigue',
#   'mucoid',
#   'sputum',
#   'cough',
#   'i',
#   'feel',
#   'fatigue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'family',
#   'history',
#   'mucoid',
#   'sputum',
#   'breathlessness',
#   'i',
#   'feel',
#   'family',
#   'history',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'breathlessness',
#   'cough',
#   'family',
#   'history',
#   'mucoid',
#   'sputum',
#   'i',
#   'feel',
#   'cough',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'family',
#   'history',
#   'cough',
#   'mucoid',
#   'sputum',
#   'i',
#   'feel',
#   'family',
#   'history',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'mucoid',
#   'sputum',
#   'family',
#   'history',
#   'breathlessness',
#   'i',
#   'feel',
#   'mucoid',
#   'sputum',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'breathlessness',
#   'fatigue',
#   'family',
#   'history',
#   'breathlessness',
#   'i',
#   'feel',
#   'fatigue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'breathlessness',
#   'mucoid',
#   'sputum',
#   'family',
#   'history',
#   'cough',
#   'i',
#   'feel',
#   'mucoid',
#   'sputum',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'cough',
#   'fatigue',
#   'family',
#   'history',
#   'i',
#   'feel',
#   'cough',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'mucoid',
#   'sputum',
#   'fatigue',
#   'cough',
#   'i',
#   'feel',
#   'mucoid',
#   'sputum',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'family',
#   'history',
#   'breathlessness',
#   'cough',
#   'i',
#   'feel',
#   'family',
#   'history',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'breathlessness',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'fatigue',
#   'mucoid',
#   'sputum',
#   'cough',
#   'i',
#   'feel',
#   'fatigue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'breathlessness',
#   'mucoid',
#   'sputum',
#   'cough',
#   'i',
#   'feel',
#   'breathlessness',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'cough',
#   'fatigue',
#   'breathlessness',
#   'family',
#   'history',
#   'i',
#   'feel',
#   'fatigue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'breathlessness',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'breathlessness',
#   'family',
#   'history',
#   'mucoid',
#   'sputum',
#   'i',
#   'feel',
#   'breathlessness',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'family',
#   'history',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mucoid',
#   'sputum'],
#  'Peptic ulcer diseae': ['loss',
#   'of',
#   'appetite',
#   'vomiting',
#   'internal',
#   'itching',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'internal',
#   'itching',
#   'vomiting',
#   'passage',
#   'of',
#   'gases',
#   'i',
#   'feel',
#   'internal',
#   'itching',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'passage',
#   'of',
#   'gases',
#   'vomiting',
#   'internal',
#   'itching',
#   'loss',
#   'of',
#   'appetite',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'internal',
#   'itching',
#   'indigestion',
#   'loss',
#   'of',
#   'appetite',
#   'i',
#   'feel',
#   'internal',
#   'itching',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'vomiting',
#   'internal',
#   'itching',
#   'loss',
#   'of',
#   'appetite',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'indigestion',
#   'loss',
#   'of',
#   'appetite',
#   'vomiting',
#   'i',
#   'feel',
#   'indigestion',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'internal',
#   'itching',
#   'vomiting',
#   'loss',
#   'of',
#   'appetite',
#   'i',
#   'feel',
#   'internal',
#   'itching',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'vomiting',
#   'loss',
#   'of',
#   'appetite',
#   'internal',
#   'itching',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'passage',
#   'of',
#   'gases',
#   'indigestion',
#   'vomiting',
#   'i',
#   'feel',
#   'passage',
#   'of',
#   'gases',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'passage',
#   'of',
#   'gases',
#   'indigestion',
#   'loss',
#   'of',
#   'appetite',
#   'i',
#   'feel',
#   'passage',
#   'of',
#   'gases',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'loss',
#   'of',
#   'appetite',
#   'vomiting',
#   'passage',
#   'of',
#   'gases',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'passage',
#   'of',
#   'gases',
#   'indigestion',
#   'passage',
#   'of',
#   'gases',
#   'internal',
#   'itching',
#   'i',
#   'feel',
#   'indigestion',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'passage',
#   'of',
#   'gases',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'vomiting',
#   'internal',
#   'itching',
#   'indigestion',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'loss',
#   'of',
#   'appetite',
#   'internal',
#   'itching',
#   'vomiting',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'loss',
#   'of',
#   'appetite',
#   'internal',
#   'itching',
#   'passage',
#   'of',
#   'gases',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'passage',
#   'of',
#   'gases',
#   'vomiting',
#   'loss',
#   'of',
#   'appetite',
#   'internal',
#   'itching',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'loss',
#   'of',
#   'appetite',
#   'internal',
#   'itching',
#   'indigestion',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'indigestion',
#   'vomiting',
#   'passage',
#   'of',
#   'gases',
#   'i',
#   'feel',
#   'indigestion',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'passage',
#   'of',
#   'gases',
#   'vomiting',
#   'passage',
#   'of',
#   'gases',
#   'loss',
#   'of',
#   'appetite',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'passage',
#   'of',
#   'gases',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'internal',
#   'itching',
#   'loss',
#   'of',
#   'appetite',
#   'indigestion',
#   'i',
#   'feel',
#   'internal',
#   'itching',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'indigestion',
#   'loss',
#   'of',
#   'appetite',
#   'passage',
#   'of',
#   'gases',
#   'i',
#   'feel',
#   'indigestion',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'passage',
#   'of',
#   'gases',
#   'passage',
#   'of',
#   'gases',
#   'vomiting',
#   'indigestion',
#   'i',
#   'feel',
#   'passage',
#   'of',
#   'gases',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'indigestion',
#   'internal',
#   'itching',
#   'vomiting',
#   'i',
#   'feel',
#   'indigestion',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'internal',
#   'itching',
#   'passage',
#   'of',
#   'gases',
#   'indigestion',
#   'i',
#   'feel',
#   'internal',
#   'itching',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'passage',
#   'of',
#   'gases',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'passage',
#   'of',
#   'gases',
#   'indigestion',
#   'internal',
#   'itching',
#   'i',
#   'feel',
#   'passage',
#   'of',
#   'gases',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'loss',
#   'of',
#   'appetite',
#   'passage',
#   'of',
#   'gases',
#   'internal',
#   'itching',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'passage',
#   'of',
#   'gases',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'vomiting',
#   'indigestion',
#   'passage',
#   'of',
#   'gases',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'passage',
#   'of',
#   'gases',
#   'passage',
#   'of',
#   'gases',
#   'indigestion',
#   'loss',
#   'of',
#   'appetite',
#   'i',
#   'feel',
#   'passage',
#   'of',
#   'gases',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'loss',
#   'of',
#   'appetite',
#   'indigestion',
#   'internal',
#   'itching',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'indigestion',
#   'passage',
#   'of',
#   'gases',
#   'vomiting',
#   'i',
#   'feel',
#   'indigestion',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'passage',
#   'of',
#   'gases',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'loss',
#   'of',
#   'appetite',
#   'indigestion',
#   'internal',
#   'itching',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'loss',
#   'of',
#   'appetite',
#   'vomiting',
#   'internal',
#   'itching',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'indigestion',
#   'loss',
#   'of',
#   'appetite',
#   'internal',
#   'itching',
#   'i',
#   'feel',
#   'indigestion',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'indigestion',
#   'internal',
#   'itching',
#   'vomiting',
#   'i',
#   'feel',
#   'indigestion',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'indigestion',
#   'loss',
#   'of',
#   'appetite',
#   'internal',
#   'itching',
#   'i',
#   'feel',
#   'indigestion',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'loss',
#   'of',
#   'appetite',
#   'vomiting',
#   'passage',
#   'of',
#   'gases',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'passage',
#   'of',
#   'gases',
#   'vomiting',
#   'internal',
#   'itching',
#   'passage',
#   'of',
#   'gases',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'passage',
#   'of',
#   'gases',
#   'vomiting',
#   'internal',
#   'itching',
#   'indigestion',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'loss',
#   'of',
#   'appetite',
#   'internal',
#   'itching',
#   'indigestion',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'loss',
#   'of',
#   'appetite',
#   'indigestion',
#   'internal',
#   'itching',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'indigestion',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching',
#   'loss',
#   'of',
#   'appetite',
#   'vomiting',
#   'internal',
#   'itching',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'internal',
#   'itching'],
#  'hepatitis A': ['abdominal',
#   'pain',
#   'vomiting',
#   'dark',
#   'urine',
#   'i',
#   'feel',
#   'abdominal',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dark',
#   'urine',
#   'mild',
#   'fever',
#   'dark',
#   'urine',
#   'loss',
#   'of',
#   'appetite',
#   'i',
#   'feel',
#   'mild',
#   'fever',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dark',
#   'urine',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'loss',
#   'of',
#   'appetite',
#   'yellowish',
#   'skin',
#   'diarrhoea',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowish',
#   'skin',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'loss',
#   'of',
#   'appetite',
#   'vomiting',
#   'yellowish',
#   'skin',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowish',
#   'skin',
#   'loss',
#   'of',
#   'appetite',
#   'abdominal',
#   'pain',
#   'diarrhoea',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'abdominal',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'dark',
#   'urine',
#   'mild',
#   'fever',
#   'abdominal',
#   'pain',
#   'i',
#   'feel',
#   'dark',
#   'urine',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mild',
#   'fever',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'abdominal',
#   'pain',
#   'mild',
#   'fever',
#   'abdominal',
#   'pain',
#   'diarrhoea',
#   'i',
#   'feel',
#   'mild',
#   'fever',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'abdominal',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'vomiting',
#   'dark',
#   'urine',
#   'nausea',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dark',
#   'urine',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea',
#   'diarrhoea',
#   'mild',
#   'fever',
#   'yellowish',
#   'skin',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mild',
#   'fever',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowish',
#   'skin',
#   'vomiting',
#   'loss',
#   'of',
#   'appetite',
#   'yellowish',
#   'skin',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowish',
#   'skin',
#   'yellowish',
#   'skin',
#   'diarrhoea',
#   'vomiting',
#   'i',
#   'feel',
#   'yellowish',
#   'skin',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'muscle',
#   'pain',
#   'yellowish',
#   'skin',
#   'joint',
#   'pain',
#   'i',
#   'feel',
#   'muscle',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowish',
#   'skin',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'joint',
#   'pain',
#   'nausea',
#   'joint',
#   'pain',
#   'abdominal',
#   'pain',
#   'i',
#   'feel',
#   'nausea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'joint',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'abdominal',
#   'pain',
#   'mild',
#   'fever',
#   'diarrhoea',
#   'yellowish',
#   'skin',
#   'i',
#   'feel',
#   'mild',
#   'fever',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowish',
#   'skin',
#   'loss',
#   'of',
#   'appetite',
#   'nausea',
#   'vomiting',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'muscle',
#   'pain',
#   'nausea',
#   'joint',
#   'pain',
#   'i',
#   'feel',
#   'muscle',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'joint',
#   'pain',
#   'joint',
#   'pain',
#   'loss',
#   'of',
#   'appetite',
#   'nausea',
#   'i',
#   'feel',
#   'joint',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea',
#   'joint',
#   'pain',
#   'vomiting',
#   'abdominal',
#   'pain',
#   'i',
#   'feel',
#   'joint',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'abdominal',
#   'pain',
#   'dark',
#   'urine',
#   'mild',
#   'fever',
#   'muscle',
#   'pain',
#   'i',
#   'feel',
#   'dark',
#   'urine',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mild',
#   'fever',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'muscle',
#   'pain',
#   'vomiting',
#   'diarrhoea',
#   'abdominal',
#   'pain',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'abdominal',
#   'pain',
#   'mild',
#   'fever',
#   'diarrhoea',
#   'vomiting',
#   'i',
#   'feel',
#   'mild',
#   'fever',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'loss',
#   'of',
#   'appetite',
#   'abdominal',
#   'pain',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'abdominal',
#   'pain',
#   'joint',
#   'pain',
#   'dark',
#   'urine',
#   'yellowish',
#   'skin',
#   'i',
#   'feel',
#   'joint',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dark',
#   'urine',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowish',
#   'skin',
#   'vomiting',
#   'muscle',
#   'pain',
#   'abdominal',
#   'pain',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'muscle',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'abdominal',
#   'pain',
#   'mild',
#   'fever',
#   'loss',
#   'of',
#   'appetite',
#   'joint',
#   'pain',
#   'i',
#   'feel',
#   'mild',
#   'fever',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'joint',
#   'pain',
#   'yellowish',
#   'skin',
#   'joint',
#   'pain',
#   'dark',
#   'urine',
#   'i',
#   'feel',
#   'yellowish',
#   'skin',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'joint',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dark',
#   'urine',
#   'loss',
#   'of',
#   'appetite',
#   'nausea',
#   'muscle',
#   'pain',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'muscle',
#   'pain',
#   'diarrhoea',
#   'dark',
#   'urine',
#   'joint',
#   'pain',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dark',
#   'urine',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'joint',
#   'pain',
#   'vomiting',
#   'diarrhoea',
#   'yellowish',
#   'skin',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowish',
#   'skin',
#   'joint',
#   'pain',
#   'vomiting',
#   'muscle',
#   'pain',
#   'i',
#   'feel',
#   'joint',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'muscle',
#   'pain',
#   'abdominal',
#   'pain',
#   'dark',
#   'urine',
#   'nausea',
#   'i',
#   'feel',
#   'abdominal',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dark',
#   'urine',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea',
#   'dark',
#   'urine',
#   'vomiting',
#   'diarrhoea',
#   'i',
#   'feel',
#   'dark',
#   'urine',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'loss',
#   'of',
#   'appetite',
#   'diarrhoea',
#   'yellowish',
#   'skin',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowish',
#   'skin',
#   'mild',
#   'fever',
#   'nausea',
#   'yellowish',
#   'skin',
#   'i',
#   'feel',
#   'mild',
#   'fever',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowish',
#   'skin',
#   'dark',
#   'urine',
#   'muscle',
#   'pain',
#   'loss',
#   'of',
#   'appetite',
#   'i',
#   'feel',
#   'dark',
#   'urine',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'muscle',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'nausea',
#   'joint',
#   'pain',
#   'mild',
#   'fever',
#   'i',
#   'feel',
#   'nausea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'joint',
#   'pain',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'mild',
#   'fever',
#   'yellowish',
#   'skin',
#   'loss',
#   'of',
#   'appetite',
#   'joint',
#   'pain',
#   'i',
#   'feel',
#   'yellowish',
#   'skin',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'joint',
#   'pain',
#   'nausea',
#   'diarrhoea',
#   'dark',
#   'urine',
#   'i',
#   'feel',
#   'nausea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'diarrhoea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dark',
#   'urine',
#   'abdominal',
#   'pain',
#   'vomiting',
#   'nausea',
#   'i',
#   'feel',
#   'abdominal',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea',
#   'diarrhoea',
#   'yellowish',
#   'skin',
#   'nausea',
#   'i',
#   'feel',
#   'diarrhoea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowish',
#   'skin',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea',
#   'abdominal',
#   'pain',
#   'dark',
#   'urine',
#   'vomiting',
#   'i',
#   'feel',
#   'abdominal',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'dark',
#   'urine',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting'],
#  'Hepatitis E': ['abdominal',
#   'pain',
#   'loss',
#   'of',
#   'appetite',
#   'vomiting',
#   'i',
#   'feel',
#   'abdominal',
#   'pain',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'loss',
#   'of',
#   'appetite',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'loss',
#   'of',
#   'appetite',
#   'yellowing',
#   'of',
#   'eyes',
#   'stomach',
#   'bleeding',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowing',
#   'of',
#   'eyes',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'bleeding',
#   'loss',
#   'of',
#   'appetite',
#   'stomach',
#   'bleeding',
#   'yellowish',
#   'skin',
#   'i',
#   'feel',
#   'loss',
#   'of',
#   'appetite',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'stomach',
#   'bleeding',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowish',
#   'skin',
#   'fatigue',
#   'vomiting',
#   'yellowing',
#   'of',
#   'eyes',
#   'i',
#   'feel',
#   'fatigue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'yellowing',
#   'of',
# ...
#   'pus',
#   'filled',
#   'pimples',
#   'skin',
#   'rash',
#   'i',
#   'feel',
#   'blackheads',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'skin',
#   'rash',
#   'blackheads',
#   'pus',
#   'filled',
#   'pimples',
#   'skin',
#   'rash',
#   'i',
#   'feel',
#   'blackheads',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'skin',
#   'rash',
#   'skin',
#   'rash',
#   'pus',
#   'filled',
#   'pimples',
#   'blackheads',
#   'i',
#   'feel',
#   'skin',
#   'rash',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'blackheads',
#   'skin',
#   'rash',
#   'pus',
#   'filled',
#   'pimples',
#   'i',
#   'feel',
#   'blackheads',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'skin',
#   'rash',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'skin',
#   'rash',
#   'blackheads',
#   'pus',
#   'filled',
#   'pimples',
#   'i',
#   'feel',
#   'skin',
#   'rash',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'skin',
#   'rash',
#   'pus',
#   'filled',
#   'pimples',
#   'blackheads',
#   'i',
#   'feel',
#   'skin',
#   'rash',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'pus',
#   'filled',
#   'pimples',
#   'blackheads',
#   'skin',
#   'rash',
#   'i',
#   'feel',
#   'pus',
#   'filled',
#   'pimples',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'skin',
#   'rash',
#   'skin',
#   'rash',
#   'blackheads',
#   'pus',
#   'filled',
#   'pimples',
#   'i',
#   'feel',
#   'skin',
#   'rash',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'blackheads',
#   'skin',
#   'rash',
#   'pus',
#   'filled',
#   'pimples',
#   'i',
#   'feel',
#   'blackheads',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'skin',
#   'rash',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'pus',
#   'filled',
#   'pimples',
#   'skin',
#   'rash',
#   'blackheads',
#   'i',
#   'feel',
#   'pus',
#   'filled',
#   'pimples',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'skin',
#   'rash',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'blackheads',
#   'pus',
#   'filled',
#   'pimples',
#   'skin',
#   'rash',
#   'i',
#   'feel',
#   'blackheads',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'skin',
#   'rash',
#   'pus',
#   'filled',
#   'pimples',
#   'skin',
#   'rash',
#   'blackheads',
#   'i',
#   'feel',
#   'pus',
#   'filled',
#   'pimples',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'skin',
#   'rash',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'skin',
#   'rash',
#   'pus',
#   'filled',
#   'pimples',
#   'blackheads',
#   'i',
#   'feel',
#   'skin',
#   'rash',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'skin',
#   'rash',
#   'blackheads',
#   'pus',
#   'filled',
#   'pimples',
#   'i',
#   'feel',
#   'skin',
#   'rash',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'skin',
#   'rash',
#   'pus',
#   'filled',
#   'pimples',
#   'blackheads',
#   'i',
#   'feel',
#   'skin',
#   'rash',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'blackheads',
#   'pus',
#   'filled',
#   'pimples',
#   'skin',
#   'rash',
#   'i',
#   'feel',
#   'blackheads',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'skin',
#   'rash',
#   'skin',
#   'rash',
#   'pus',
#   'filled',
#   'pimples',
#   'blackheads',
#   'i',
#   'feel',
#   'skin',
#   'rash',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'blackheads',
#   'skin',
#   'rash',
#   'pus',
#   'filled',
#   'pimples',
#   'i',
#   'feel',
#   'blackheads',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'skin',
#   'rash',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'pus',
#   'filled',
#   'pimples',
#   'skin',
#   'rash',
#   'blackheads',
#   'i',
#   'feel',
#   'pus',
#   'filled',
#   'pimples',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'skin',
#   'rash',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'skin',
#   'rash',
#   'pus',
#   'filled',
#   'pimples',
#   'blackheads',
#   'i',
#   'feel',
#   'skin',
#   'rash',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'pus',
#   'filled',
#   'pimples',
#   'skin',
#   'rash',
#   'blackheads',
#   'i',
#   'feel',
#   'pus',
#   'filled',
#   'pimples',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'skin',
#   'rash',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'skin',
#   'rash',
#   'pus',
#   'filled',
#   'pimples',
#   'blackheads',
#   'i',
#   'feel',
#   'skin',
#   'rash',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'pus',
#   'filled',
#   'pimples',
#   'skin',
#   'rash',
#   'blackheads',
#   'i',
#   'feel',
#   'pus',
#   'filled',
#   'pimples',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'skin',
#   'rash',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'skin',
#   'rash',
#   'blackheads',
#   'pus',
#   'filled',
#   'pimples',
#   'i',
#   'feel',
#   'skin',
#   'rash',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blackheads',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'pus',
#   'filled',
#   'pimples'],
#  'Hypoglycemia': ['palpitations',
#   'excessive',
#   'hunger',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'i',
#   'feel',
#   'palpitations',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'excessive',
#   'hunger',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'anxiety',
#   'palpitations',
#   'irritability',
#   'i',
#   'feel',
#   'anxiety',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'palpitations',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'irritability',
#   'slurred',
#   'speech',
#   'sweating',
#   'irritability',
#   'i',
#   'feel',
#   'slurred',
#   'speech',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'sweating',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'irritability',
#   'anxiety',
#   'palpitations',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'i',
#   'feel',
#   'anxiety',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'palpitations',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'sweating',
#   'nausea',
#   'i',
#   'feel',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'sweating',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea',
#   'sweating',
#   'anxiety',
#   'excessive',
#   'hunger',
#   'i',
#   'feel',
#   'sweating',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'anxiety',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'excessive',
#   'hunger',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'excessive',
#   'hunger',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'i',
#   'feel',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'excessive',
#   'hunger',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'irritability',
#   'sweating',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'i',
#   'feel',
#   'irritability',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'sweating',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'palpitations',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'excessive',
#   'hunger',
#   'i',
#   'feel',
#   'palpitations',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'excessive',
#   'hunger',
#   'slurred',
#   'speech',
#   'excessive',
#   'hunger',
#   'vomiting',
#   'i',
#   'feel',
#   'slurred',
#   'speech',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'excessive',
#   'hunger',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'fatigue',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'i',
#   'feel',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'irritability',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'vomiting',
#   'i',
#   'feel',
#   'irritability',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'vomiting',
#   'excessive',
#   'hunger',
#   'sweating',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'excessive',
#   'hunger',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'sweating',
#   'nausea',
#   'anxiety',
#   'fatigue',
#   'i',
#   'feel',
#   'nausea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'anxiety',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'nausea',
#   'irritability',
#   'vomiting',
#   'i',
#   'feel',
#   'nausea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'irritability',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'anxiety',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'slurred',
#   'speech',
#   'i',
#   'feel',
#   'anxiety',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'slurred',
#   'speech',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'fatigue',
#   'anxiety',
#   'i',
#   'feel',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'anxiety',
#   'palpitations',
#   'sweating',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'i',
#   'feel',
#   'palpitations',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'sweating',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'irritability',
#   'vomiting',
#   'excessive',
#   'hunger',
#   'i',
#   'feel',
#   'irritability',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'excessive',
#   'hunger',
#   'nausea',
#   'palpitations',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'i',
#   'feel',
#   'nausea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'palpitations',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'vomiting',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'fatigue',
#   'i',
#   'feel',
#   'vomiting',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'anxiety',
#   'nausea',
#   'sweating',
#   'i',
#   'feel',
#   'anxiety',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'sweating',
#   'irritability',
#   'slurred',
#   'speech',
#   'sweating',
#   'i',
#   'feel',
#   'irritability',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'slurred',
#   'speech',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'sweating',
#   'palpitations',
#   'fatigue',
#   'slurred',
#   'speech',
#   'i',
#   'feel',
#   'palpitations',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'slurred',
#   'speech',
#   'irritability',
#   'anxiety',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'i',
#   'feel',
#   'irritability',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'anxiety',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'nausea',
#   'vomiting',
#   'excessive',
#   'hunger',
#   'i',
#   'feel',
#   'nausea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'excessive',
#   'hunger',
#   'slurred',
#   'speech',
#   'vomiting',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'i',
#   'feel',
#   'slurred',
#   'speech',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'vomiting',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'sweating',
#   'fatigue',
#   'anxiety',
#   'i',
#   'feel',
#   'sweating',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'anxiety',
#   'nausea',
#   'sweating',
#   'slurred',
#   'speech',
#   'i',
#   'feel',
#   'nausea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'sweating',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'slurred',
#   'speech',
#   'irritability',
#   'sweating',
#   'palpitations',
#   'i',
#   'feel',
#   'irritability',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'sweating',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'palpitations',
#   'sweating',
#   'excessive',
#   'hunger',
#   'anxiety',
#   'i',
#   'feel',
#   'sweating',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'excessive',
#   'hunger',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'anxiety',
#   'fatigue',
#   'sweating',
#   'irritability',
#   'i',
#   'feel',
#   'fatigue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'sweating',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'irritability',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'fatigue',
#   'palpitations',
#   'i',
#   'feel',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'fatigue',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'palpitations',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'anxiety',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'i',
#   'feel',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'anxiety',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'palpitations',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'nausea',
#   'i',
#   'feel',
#   'palpitations',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'blurred',
#   'and',
#   'distorted',
#   'vision',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea',
#   'nausea',
#   'irritability',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'i',
#   'feel',
#   'nausea',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'irritability',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'palpitations',
#   'anxiety',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'i',
#   'feel',
#   'palpitations',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'anxiety',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'fatigue',
#   'palpitations',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'i',
#   'feel',
#   'fatigue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'palpitations',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'drying',
#   'and',
#   'tingling',
#   'lips',
#   'palpitations',
#   'nausea',
#   'irritability',
#   'i',
#   'feel',
#   'palpitations',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'irritability',
#   'anxiety',
#   'palpitations',
#   'irritability',
#   'i',
#   'feel',
#   'anxiety',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'palpitations',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'irritability',
#   'fatigue',
#   'excessive',
#   'hunger',
#   'nausea',
#   'i',
#   'feel',
#   'fatigue',
#   'and',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'excessive',
#   'hunger',
#   'but',
#   'i',
#   'also',
#   'feel',
#   'like',
#   'nausea']}

# %% [markdown]
# Now that we have a trained Markov Chain, we can quickly set up a sentence generation function to create all the sentences per each condition, we we can then add to a json file and export to the database

# %%
def gen_sent(model,max_words,symp):
 
    n = 0
    curr_state = symp
    next_state = None
 
    sent = ""
    sent+=curr_state+" "
 
    while n < max_words:
        next_state = random.choices(list(model[curr_state].keys()),
                                    list(model[curr_state].values()))
       
        curr_state = next_state[0]
        sent+=curr_state+" "
        n+=1
 
    return sent

def implement_sent_gen(model,arr):
    out = []
    for i in range(len(arr)):
        if arr[i] in model.keys():
            for j in range(30):
                    out.append(gen_sent(model,15,symp=arr[i]))
    print(len(out))      
    return out

# %%
#get the conditions and sentences
generated_sents = {}
for condition in list(values.keys()):
    model = mcms.get(condition)
    symps = values2.get(condition)

    separatedSymps = []
    for symp in symps:
        separatedSymps += symp.split(" ")
    

    generated_sents[condition] = []

    for i in range(10):
        sentence = implement_sent_gen(model,separatedSymps)
        generated_sents[condition].extend(sentence)
# Out:
# 90
# 90
# 90
# 90
# 90
# 90
# 90
# 90
# 90
# 90
# 270
# 270
# 270
# 270
# 270
# 270
# 270
# 270
# 270
# 270
# 210
# 210
# 210
# 210
# 210
# 210
# 210
# 210
# 210
# 210
# 300
# 300
# 300
# 300
# 300
# 300
# 300
# 300
# 300
# 300
# 570
# 570
# 570
# 570
# 570
# 570
# 570
# 570
# 570
# 570
# 690
# 690
# 690
# 690
# 690
# 690
# 690
# 690
# 690
# 690
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 180
# 180
# 180
# 180
# 180
# 180
# 180
# 180
# 180
# 180
# 270
# 270
# 270
# 270
# 270
# 270
# 270
# 270
# 270
# 270
# 450
# 450
# 450
# 450
# 450
# 450
# 450
# 450
# 450
# 450
# 210
# 210
# 210
# 210
# 210
# 210
# 210
# 210
# 210
# 210
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 330
# 330
# 330
# 330
# 330
# 330
# 330
# 330
# 330
# 330
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 690
# 690
# 690
# 690
# 690
# 690
# 690
# 690
# 690
# 690
# 300
# 300
# 300
# 300
# 300
# 300
# 300
# 300
# 300
# 300
# 360
# 360
# 360
# 360
# 360
# 360
# 360
# 360
# 360
# 360
# 360
# 360
# 360
# 360
# 360
# 360
# 360
# 360
# 360
# 360
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 330
# 330
# 330
# 330
# 330
# 330
# 330
# 330
# 330
# 330
# 810
# 810
# 810
# 810
# 810
# 810
# 810
# 810
# 810
# 810
# 330
# 330
# 330
# 330
# 330
# 330
# 330
# 330
# 330
# 330
# 180
# 180
# 180
# 180
# 180
# 180
# 180
# 180
# 180
# 180
# 750
# 750
# 750
# 750
# 750
# 750
# 750
# 750
# 750
# 750
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 300
# 300
# 300
# 300
# 300
# 300
# 300
# 300
# 300
# 300
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 390
# 510
# 510
# 510
# 510
# 510
# 510
# 510
# 510
# 510
# 510
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 450
# 450
# 450
# 450
# 450
# 450
# 450
# 450
# 450
# 450
# 480
# 480
# 480
# 480
# 480
# 480
# 480
# 480
# 480
# 480
# 840
# 840
# 840
# 840
# 840
# 840
# 840
# 840
# 840
# 840
# 600
# 600
# 600
# 600
# 600
# 600
# 600
# 600
# 600
# 600
# 420
# 420
# 420
# 420
# 420
# 420
# 420
# 420
# 420
# 420
# 420
# 420
# 420
# 420
# 420
# 420
# 420
# 420
# 420
# 420
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 660
# 660
# 660
# 660
# 660
# 660
# 660
# 660
# 660
# 660
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 240
# 180
# 180
# 180
# 180
# 180
# 180
# 180
# 180
# 180
# 180
# 570
# 570
# 570
# 570
# 570
# 570
# 570
# 570
# 570
# 570

# %%
#generated_sents.get("AIDS")

# %%
len(list(generated_sents.keys()))
# Out:
# 41
